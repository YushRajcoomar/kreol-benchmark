# %%
import PyPDF2
import re
import pandas as pd
import numpy as np

# %%
def extract_text_from_pdf(pdf_path):
    text = ''
    with open(pdf_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)
        num_pages = len(pdf_reader.pages)
        for page_num in range(num_pages):
            page = pdf_reader.pages[page_num]
            text += page.extract_text()
    return text

# %%
pdf_path = r"/mnt/disk/yrajcoomar/kreol-benchmark/data_collection/books/diksioner.pdf"
extracted_text = extract_text_from_pdf(pdf_path)
pdf_reader = PyPDF2.PdfReader(pdf_path)

# %% [markdown]
# ### Parsing Strategy

# %%
word_def_list = [] #to parse as well into bitext
cr_en_bitext_list = [] #to parse into
triage_list = [] #leftover, error catching
len_header = len('DIKS YON ER KREOL MORISYEN  \n \n')
for page in range(1,len(pdf_reader.pages)):
    text_page = pdf_reader.pages[page].extract_text().strip(' ')
    page_str = len(str(page+1))
    header_strip_len = len_header + page_str
    sentences = text_page[header_strip_len:].strip(' ').lstrip('\n').split('.')
    for sentence in sentences:
        if '[' in sentence: # Definitions in the dict tend to have square brackets to denote etymological sources.
            word_def_list.append((page,sentence))
        elif '=' in sentence: # Bitext in the dict tends to have equal signs
            cr_en_bitext_list.append((page,sentence))
        else: # Above 2 conditions are expected to catch atleast 80% of data correctly
            if len(sentence) > 1:
                triage_list.append((page,sentence))

# %% [markdown]
# ## Post parsing Clean

# %% [markdown]
# ### definitions

# %%
clean_word_def_list = []
double_brackets_list = []
for pg,txt in word_def_list:
    if txt.count('[') > 1:
        double_brackets_list.append((pg,txt))
    else:
        clean_txt = txt.replace('\n','').replace('  ',' ')
        clean_word_def_list.append((pg,clean_txt.strip(' ')))

# %%
single_bkt_list = []
for pg,txt in double_brackets_list:
    tl = txt.replace('\n',' ').split('   ')
    for x in tl:
        if len(x) > 0:
            single_bkt_list.append((pg,x.strip(' ')))

# %%
single_bkt_list
# Out:
# [(2, 'abi [from Fre abus] : abuse'),
#  (2, 'abitan  [from Fre habitant] : inhabitant'),
#  (3, 'abitiye  [from Fre habituer] : to accustom'),
#  (3, 'abiye  [from Fre habiller] : to dress'),
#  (3, 'abize  [from Fre abuser] :  to abuse'),
#  (3, 'abor  [from Fre a bord] : on board'),
#  (3, 'absan  [from Fre absent] : absent'),
#  (3, 'absans  [from Fre absence] : absence'),
#  (4, 'absorbe  [from Fre absorber] : to absorb'),
#  (4, 'adimans  [from Fre a dimanche] : to  Sunday'),
#  (5, 'akonpanye  (akonpayn) [from Fre  accompagner] : to accompany'),
#  (5, 'akonpli  [from Fre accomplir] : to  accomplish'),
#  (10, 'alorizinn  [from Fre a l’origine] : originally'),
#  (10, 'alwil  [from Fre a l’huile] : of oil'),
#  (11, 'amize  [from Fre amuser] : to have fun'),
#  (11, 'amizir  [from Fre a mesure] : to the extent  (of)'),
#  (13, 'anbarase  (anbaras) [from Fre embarrasser]  :  to embarrass'),
#  (13, 'anbasader  [from Fre ambassadeur] :  ambassador'),
#  (13, 'anbrase  [from Fre embrasser] : to embrace;  to kiss'),
#  (13, 'anbrik  [from Fre en brique] : of brick'),
#  (14, 'andat  [from Fre en date] : dated (as)'),
#  (14, 'andemik  [from Fre endemique] : native;  innate'),
#  (16, 'anile  [from Fre annuler] : to cancel'),
#  (16, 'anka  [from Fre en  cas] : in case (of)'),
#  (17,
#   'ankonsiderasyon  [from Fre en  consideration] : considering; in exchange  (of)  ankor  [from Fre encore] : still'),
#  (19, 'anord  [from Fre en or dre] : in order'),
#  (19, 'anpann  [from Fre en panne] : having a  breakdown'),
#  (21, 'anplwaye  [from Fre employer] : to employ'),
#  (21, 'anplwayer  [from Fre employeur] :  employer'),
#  (21, 'anprensip  [from Fre en principle] : in  principle'),
#  (22, 'anprofonder  [from Fre en profondeur] : in  depth'),
#  (22, 'anpromye  [from *en promier from Fre en  premier] : at first'),
#  (22, 'anrad  [from Fre en rade] : at anchor'),
#  (22, 'anrisi  [from Fre enrichir] : to enrich'),
#  (23, 'ansenye  (anseyn)  [from Fre enseigner] : to  teach'),
#  (23, 'ansorsele  [from Fre ensorceler] : to  bewitch; to e nchant'),
#  (23, 'answit  [from Fre ensuite] : afterwards'),
#  (23, 'ansyen  [from Fre ancien] : ancient'),
#  (23, 'ant [from Fre entre] : between'),
#  (24, 'antisipe  (antisip)  [from Fre anticiper] : to  anticipate'),
#  (24, 'antor  [from Fre en tort] : in the wrong'),
#  (25, 'antretan  [from Fre entretemps] : in  between'),
#  (25, 'antu  [from F re en tout] : alltogether'),
#  (27, 'anviron  [from Fre environ] : around;  approximately'),
#  (27, 'anvites  [from Fre en vitesse] :  speedily'),
#  (28, 'apel [from Fre appel] : call'),
#  (28, 'apele  (apel) [from Fre appeler] : to call'),
#  (31, 'asasine  [from Fre assassiner] : to  assassinate'),
#  (31, 'ase [from Fre assez] : enough'),
#  (38, 'ayi [from Fre hair] : to hate'),
#  (38, 'ayisyen  [from Fre haitien] : Haitian'),
#  (38, 'azi [from Fre agir] : to act'),
#  (38, 'aziste  [from Fre adjuster] : to adjust'),
#  (39, 'badinaz  [from Fre badinage] : fun;  amusement'),
#  (39, 'bag [from Fre bague] : ring'),
#  (39, 'bagaz  [from Fre bagage] : baggage'),
#  (39, 'bal [from Fre balle] : bullet'),
#  (41, 'batem  [from Fre bapteme] : baptism'),
#  (41, 'batiman  [from Fre batiment] : building'),
#  (41, 'bato  [from Fre bateau] : boat'),
#  (42, 'bef [from Fre boeuf] : beef; ox'),
#  (42, 'bel [from Fre bel(le)] : large'),
#  (42, 'benye  (beyn) [f rom Fre baigner] : to bathe'),
#  (42, 'berse  (bers) [from Fre bercer] : to rock'),
#  (42, 'bese (bes) [from Fre baisser] : to lower'),
#  (44, 'bizu [from Fre bijou] : cheap jewel'),
#  (44, 'blan  [from Fre blanc] : white'),
#  (44, 'ble [from Fre bleu] : blue'),
#  (44, 'blem  [from Fre bleme] : pale'),
#  (46, 'bonswar  [from Fre bonsoir] : good evening'),
#  (46, 'bonzur  [from Fre bonjour] : good morning'),
#  (47, 'brans  [from Fre branche] : branch'),
#  (47, 'brasle  [from Fre bracelet] : bracelet'),
#  (48, 'brenzel  [from Fre aubergine] : egg -plant'),
#  (48, 'briani  [from Hin] : a rice dish'),
#  (48, 'brik [from Fre brique] : brick'),
#  (48, 'brile  [from Fre bruler] : to burn'),
#  (48, 'brin [from Fre brun] : brown'),
#  (48, 'brit [from Fre brut] : rough'),
#  (48, 'briye  (2) : shine; flash'),
#  (48, 'bude  [from Fre bouder] : to sulk'),
#  (48, 'buku  [from Fre beaucoup] : many; a lot'),
#  (51, 'bwi [from Fre bouillir] : to boil'),
#  (51, 'byen  [from Fre bien] : well; very'),
#  (56, 'dayer  [from Fre d’ailleurs] : by the way'),
#  (56, 'de [from Fre deux] : two'),
#  (58, 'defans  [from Fre défence] : defence'),
#  (58, 'deferle  [from Fre déferler] : to unfurl'),
#  (58, 'defo [from Fre défaut] : default'),
#  (58, 'dedikas  [from Fre dédicace] : dedication'),
#  (60, 'denn  [from Fre dinde] : turkey'),
#  (60, 'denor  [from *dé nord from Fre  nord] :  northern'),
#  (62, 'depite  [from Fre députe] : deputy'),
#  (62,
#   'deplizanpli  [from *dé plus en plus from  Fre de plus en plus] : more and more'),
#  (62, 'deranze  (deranz) [from Fre déranger] : to  disturb'),
#  (63, 'desam  [from Fre décembre] : December'),
#  (63, 'dese [from Fre déces] : death'),
#  (65,
#   'detutfason  [from *dé toute facon from Fre  de toute  facon] : at any rate'),
#  (65, 'devi [from *dé vie from Fre de vie] : of  life'),
#  (68, 'dezer  (2) [from Fre deux heures] : two  hours'),
#  (68, 'dezespwar  [from Fre désespoir] : despair'),
#  (69, 'diab  [from Fre diable] : devil'),
#  (69, 'diaman  [from Fre diamant] : diamond'),
#  (69, 'diber  [from Fre b eurre] : butter'),
#  (69, 'dible  [from Fre ble] : wheat'),
#  (70, 'dibwa  [from Fre bois] : wood (as material)'),
#  (70, 'dibyen  [from byen] : possession'),
#  (70, 'dibyene  (dibyen) [from byen] : to possess'),
#  (70, 'difil [from Fre fil] : wire'),
#  (70, 'difisil  [from Fre difficile] : difficult'),
#  (71, 'diktater  [from Fre dictateur] : dictator'),
#  (71, 'dile [from Fre lait] : milk'),
#  (71, 'dilwil  [see alwil] : oil'),
#  (71, 'dimann  [from Fre demander] : to ask'),
#  (71, 'dimans  [from Fre dimanche] : Sunday'),
#  (71, 'dimen  [from Fre demain] : tomorrow'),
#  (73,
#   'dinamik  [from Fre dinamique] :  dyna mic  dipen  [from Fre pain] : bread'),
#  (74, 'dipi (3) [from Fre pus] : pus'),
#  (74, 'diplom  [from Fre plombe] : lead (metal)'),
#  (74, 'dipwav  [from Fre poivre] : pepper'),
#  (74, 'dir (1) [from Fre dire] : to say'),
#  (74, 'dir (2) [from Fre dur] : hard'),
#  (74, 'dire [from Fre durer] : to last'),
#  (74, 'direksyon  [from Fre direction] : direction'),
#  (75, 'disan  [from Fre sang] : blood'),
#  (75, 'disann  [from Fre descendre] : to  descend'),
#  (75, 'disel  [from Fre sel] : salt'),
#  (75, 'disela  [from Fre de cela] : ago'),
#  (76, 'disiplinn  [from Fre discipline] : discipline'),
#  (76, 'diskur  [from Fre discourse] :  discourse'),
#  (77, 'dite [from Fre the] : tea'),
#  (77, 'ditu [from Fre de tout] : at all'),
#  (78, 'diven  [from Fre vin] : w ine  dizan  [from Fre dix ans] : ten years'),
#  (78, 'dizef  [from Fre oeuf] : egg'),
#  (78, 'dizenn  [from Fre dixaine] : ten;  decade'),
#  (78, 'dizer  [from Fre dix heures] : ten hours'),
#  (78, 'dizyem  [from Fre dixieme] : tenth'),
#  (78, 'dodo  [from Fre dodo] : sleep'),
#  (79, 'domaz  [from Fre dommage] : pity'),
#  (79, 'done  (donn) [from Fre donner] : to give'),
#  (82, 'duzyem  [from Fre douzieme] : twelfth'),
#  (82, 'dwatet  [from Fre doit etre] : maybe'),
#  (83, 'eberze  [from Fre heberger] : to  accommodate'),
#  (83, 'ede (ed) [from Fre aider] : to help'),
#  (84, 'egi [from Fre aigu] : acute'),
#  (84, 'egl [from Fre aigle] : eagle'),
#  (84, 'egzamine  [from Fre examiner] : to examine'),
#  (84, 'egzanp  [from Fre exemple] : exemple'),
#  (85, 'egzazerasyon  [from Fre exageration] :  exaggeration'),
#  (85, 'egzazere  [from Fre exagerer] : to  exaggerate'),
#  (88, 'eksplore  (eksplor) [from Fre explorer] : to  explore'),
#  (88, 'ekspres  [from Fre expres] : express'),
#  (89, 'elegan  [from Fre elegant] : elegant'),
#  (89, 'elegans  [from Fre elegance] : elegance'),
#  (89, 'eli [from Fre el u] : elected'),
#  (89, 'elve [from Fre elever] : to raise'),
#  (91,
#   'enb [from Fre  humble ] : humbl e  endisiplinn  [from Fre indiscipline] :  indiscipline'),
#  (91, 'enflyans  [from Fre influence] : influence'),
#  (91, 'enimen  [from Fre inhumain] : inhuman'),
#  (91, 'enitil  [from Fre inutil] : useless'),
#  (92, 'enkwayab  [from Fre incroyable] :  incredible'),
#  (92, 'enn [from Fre un] : one'),
#  (94, 'entak  [from Fre intact] : intact'),
#  (94, 'entelizan  [from Fre intelligent] : inte lligent'),
#  (94, 'enteresan  [from Fre inter essant] :  interesting'),
#  (94, 'envante  [from Fre inventer] : to invent'),
#  (94, 'envesti  [from Fre investir] : to invest'),
#  (95, 'enzekte  [from Fre injecter] : to inject'),
#  (95, 'enzenye  [from Fre ingenieur] : engineer'),
#  (96, 'erezman  [from Fre heur eusement] : luckily'),
#  (96, 'erite  [from Fre heriter] : to inherit'),
#  (97, 'etranz  [from Fre etrange] : strange; foreign'),
#  (97, 'etranze  [from Fre etranger] : stranger ;  foreign er'),
#  (99, 'fakter  [from Fre facteur] : factor'),
#  (99, 'fale [from Fre fallait] : should'),
#  (99, 'fam [from Fre femme] : wife'),
#  (99, 'fami  [from Fre famille] : family'),
#  (100, 'fann  [from Fre fendre] : to cleave'),
#  (100, 'fant [from Fre fente] : cleft'),
#  (100, 'farata  [from Hin] : flat bread'),
#  (100, 'fas [from Fre face] : face'),
#  (101, 'fatigan  [from Fre fatigant] : exhausting'),
#  (101, 'fatige  [from Fre fatiguer] : to exhaust'),
#  (102, 'febles  [from Fre faiblesee] : weakness'),
#  (102,
#   'fek [from Fre fait que]  verbal aspect  : Mo  fek leve = I hardly awoke'),
#  (102, 'femel  [from Fre femelle] : female'),
#  (102, 'fenwar  [from fer + nwar] : darkness'),
#  (103, 'feray  [from Fre ferraille] : (junk) iron'),
#  (103, 'ferme  (ferm) [from Fre fermer] : to close'),
#  (103, 'fevrye  [from Fre fevrier] : February'),
#  (103, 'fey [from Fre feuille] : leaf; sheet'),
#  (104, 'finalman  [from Fre finalement] : finally'),
#  (104, 'fini [from Fre finir] : to finish'),
#  (105, 'firi [from Fre furie] : fury'),
#  (105, 'fite [from Fre futer] : to sharpen'),
#  (105, 'fitir [from Fre future] : future'),
#  (105, 'fizi [from Fre fusil] : rifle'),
#  (108, 'franse  [from Fre francais] : French'),
#  (108, 'frape  (frap) [from Fre frapper] : to stir'),
#  (109, 'fri [from Fre fruit] : fruit'),
#  (109, 'frizider  [from “frigidaire”] : refrigerator'),
#  (109, 'fron [from Fre front] : forehead'),
#  (110, 'fuset  [from Fre fourchette] : fork'),
#  (110,
#   'fut [from Fre foutre] :  Alerman komers  ilegal mendev la ti pe fer fut ek tu sa bann'),
#  (111, 'fyer [from Fre fier] : proud'),
#  (111, 'fyerte  [from Fre fierte] : pride'),
#  (114, 'gate (2) : darling'),
#  (114, 'gato [from Fre gateau] : cake'),
#  (114, 'gayar  [from Fre gaillard] : brave'),
#  (114, 'geri [from Fre guerir] : to heal'),
#  (114, 'gete (get) [from Fre guetter] : to look'),
#  (117, 'grav  [from Fre grave] : grave; serious'),
#  (117, 'grif [from Fre griffe] : claw'),
#  (117, 'grife  [from Fre griffer] : to scatch'),
#  (117, 'grifone  [from Fre griffonner] : to scribble'),
#  (118, 'griye  [from Fre griller] : to roast'),
#  (118, 'gro [from Fre gros] : big, wide, fat'),
#  (119, 'guverner  [from Fre gouverneur] : governor'),
#  (119, 'guvernman  [from Fre gouvernement] :  government'),
#  (119, ''),
#  (120, 'ideolozik  [from Fre ideologique] :  ideological'),
#  (120, 'ilimine  (iliminn) [from Fre  illumine] :'),
#  (120, 'illuminated'),
#  (120, 'ilser [from Fre ulcere] : ulcer'),
#  (120, 'imans  [from Fre immense] : immense'),
#  (121, 'imid  [from Fre humide] : humid'),
#  (121, 'ini [from Fre uni] : united'),
#  (121, 'inik [from Fre unique] : unique'),
#  (121, 'irben  [from Fre urbain] : urban'),
#  (121, 'irn [from Fre urne] : urn'),
#  (124, 'kales [from Fre caleche] : carriage'),
#  (124, 'kalite  [from Fre qualite] : quality'),
#  (129, 'kas [from Eng] : cash'),
#  (129, 'kase  (kas) [from Fre casser] : to break'),
#  (130, 'katorzyem  [from Fre quatorzieme] :  fourteenth'),
#  (130, 'katran  [from Fre quatre ans] : four years'),
#  (131, 'kayer  [from Fre cahier] : excercise book'),
#  (131, 'kenz  [from Fre quinze] : fiftteen'),
#  (131, 'kenzyem  [from Fre quinzieme] : fifteenth'),
#  (131, 'kes [from Fre caisse] : case; box'),
#  (133, 'kiltir  [from Fre culture] : culture'),
#  (133, 'kiltirel  [from Fre culturel] : cultural'),
#  (133, 'kiltive  (kiltiv) [from Fre cultiver] : to  cultivate'),
#  (135, 'klu [from Fre clou] : nail'),
#  (135, 'kof [from Fre coffre] : case; box'),
#  (135, 'kok [from Fre coq] : cock'),
#  (135, 'koken  [from Fre coquin] : rascal; thief'),
#  (135, 'koko  [from Fre coco] : coconut; head'),
#  (135, 'komdabitid  [from Fre comme d’habitude] :  as always'),
#  (135, 'komen  [from Fre commun] : common'),
#  (135, 'komete  (komet) [from Fre commettre] : to  commit'),
#  (136, 'kominyan  [from Fre communion] :  communion'),
#  (136, 'komye  [from Fre combien] : how many'),
#  (138, 'konpare  [from Fre comparer] : to compare'),
#  (138, 'konparezon  [from Fre comparaison] :  comparison'),
#  (138, 'konplike  [from Fre complique] :  complicated'),
#  (139, 'konpreansyon  [from Fre comprehension] :  comprehension'),
#  (139, 'konsernan  [from Fre concernant] :  concerning'),
#  (139, 'konseye  (konsey) [from Fre conseiller] : to  advise'),
#  (140, 'konstrir  [from Fre construire] : to construct'),
#  (140, 'konsyan  [from Fre conscient] :  conscious'),
#  (142,
#   'konteni  [from Fre contenu] : cont ent  kontribiye  [from Fre contribuer] : to  contribute'),
#  (142,
#   'konze  [from Fre conge] : vacation,  Kan mo  ti pu gayn konze = When would I get  vacation'),
#  (145, 'kravat  [from Fre cravate] : tie'),
#  (145, 'krayon  [from Fre crayon] : pencil'),
#  (145, 'kraze  [from Fre ecraser] : to crush'),
#  (145, 'kreater  [from Fre createur] : to creator'),
#  (145, 'kree  (kre) [from Fre creer] : to create'),
#  (147, 'kud [from Fre coude] : elbow'),
#  (147, 'kule (kul) [from Fre couler] : to flow'),
#  (148, 'kulev  [from Fre couleuvre] : water -snake'),
#  (148, 'kuma  [from Fre comment] : like'),
#  (150, 'kurupa  [from Ban] : snail'),
#  (150, 'kuse  [from Fre coucher] : to set'),
#  (151, 'kute  [from Fre couter : to cost'),
#  (151, 'kuto  [from Fre couteau] : knife'),
#  (151, 'kuyer  [from Fre cueillere] : spoon'),
#  (151, 'kuzen  [from Fre cousin] : cousin'),
#  (152, 'kwi [from Fre cuit] : cooked'),
#  (152, 'kwizinn  [from Fre cuisine] : kitchen'),
#  (152, ''),
#  (153, 'labek  [from Fre bec] : beak'),
#  (153, 'Labib  [from Fre Bible] : Bible'),
#  (153, 'labitid  [from Fre habitude] : habit'),
#  (154, 'laburer  [from Fre laboureur] : laborer'),
#  (154, 'labutik  [from Fre boutique] : shop'),
#  (154, 'labus  [from Fre bouche] : mouth'),
#  (154, 'labuzi  [from Fre bougie] : candle'),
#  (154, 'labwason  [from Fre boisson] : drink'),
#  (154, 'ladan  [from Fre la dans] : inside'),
#  (155, 'ladob  [from Fre daube] : mocking'),
#  (155, 'ladrog  [from Fre drogue] : drog'),
#  (155, 'ladwann  [from Fre douane] : customs'),
#  (155, 'laenn  [from Fre haine] : hate'),
#  (155, 'lafatig  [from Fre fatigue] : exhaustion'),
#  (156, 'lafime  [from Fre fumee] : smoke'),
#  (156, 'lafisel  [from Fre ficelle] : cord'),
#  (156, 'lafors  [from Fre force] : force'),
#  (156, 'laflam  [from Fre flamme] : flame'),
#  (158, 'lagar  [from Fre gare] : station'),
#  (158, 'lagazet  [from Fre gazette] : newspaper'),
#  (158, 'lagel  [from Fre gueule] : mouth'),
#  (158, 'lager  [from Fre guerre] : war; battle'),
#  (158, 'laglas  [from Fre glace] : ice; mirror'),
#  (158, 'lagli [from Fre glu] : glue'),
#  (158, 'lagorz [from Fre gorge] : throat'),
#  (158, 'lagras  [from Fre grace] : grace'),
#  (158, 'lagrenn  [from Fre graine] : grain'),
#  (160, 'lakol  [from Fre colle] : glue'),
#  (160, 'lakoler  [from Fre colere] : anger'),
#  (160, 'lakomedi  [from Fre comedie] : comedy'),
#  (160, 'lakord  [from Fre corde] : cord'),
#  (161, 'lalang  [from Fre langue] : tongue'),
#  (161, 'lalenn  [from Fre laine] : woo l  lalev  [from Fre levre]  : lip'),
#  (162, 'lalis [from Fre liste] : list'),
#  (162, 'lalit [from Fre lutte] : fight'),
#  (162, 'lamans  [from Fre manche] : sleeve; handle'),
#  (162, 'lamare  [from Fre maree] : tide; flood'),
#  (162, 'lamars  [from Fre marche] : march'),
#  (164, 'lameson  [from Fre hamecon] : hammock'),
#  (164, 'lamitye  [from Fre amitie] :  friendship'),
#  (165, 'lamod  [from Fre mode] : fashion'),
#  (165, 'lamor  [from Fre mort] : death'),
#  (165, 'lamori  [from Fre morue] : cod'),
#  (165, 'lamur  [from Fre amour] : love'),
#  (166, 'lan [from Fre lent] : slow'),
#  (166, 'lanaliz  [from Fre analyse] : analysis'),
#  (166, 'lanatir  [from Fre nature] : nature'),
#  (166, 'lanbilans  [from Fre ambulance] :  ambulance'),
#  (167, 'langar  [from Fre hangar] : hangar'),
#  (167, 'langaz  [from Fre langage] :  language'),
#  (167, 'langre  [from Fre  engrais] : manure'),
#  (167, 'laniverser  [from Fre anniversaire] :  anniversary'),
#  (168, 'lanons  [from Fre annonce] : announcement;  advertisement'),
#  (168, 'lanos  [from Fre noce] : wedding'),
#  (168, 'lanpader  [from Fre lampadere] : street  lamp'),
#  (169, 'lanplwaye  [from Fre employe] : employee'),
#  (169, 'lanse  (lans) [from Fre lancer] : to launch'),
#  (169, 'lanset  [from Fre ancetre] : ancestor'),
#  (169, 'lanterpriz  [from Fre enterprise] : enterprise'),
#  (170, 'lanwarte  [from Fre noirete] : darkness;  distress'),
#  (170, 'lanwit  [from Fre nuit] : night'),
#  (171, 'lapa [from Fre appat]  : bait'),
#  (171, 'laparans  [from Fre apparence] :  appearence'),
#  (171, 'laparey  [from Fre appareil] : apparatus;  device'),
#  (171, 'lapat  [from Fre patte] : paw'),
#  (171, 'lapate  [from Fre pate] : paste'),
#  (171, 'lapay  [from Fre paille] : straw'),
#  (172, 'laper  [from Fre peur] : fear'),
#  (172, 'lapert  [from Fre perte] : loss'),
#  (172, 'lapes  [from Fre peche] : peach'),
#  (172, 'laplas  [from Fre place] : place'),
#  (173, 'lapli  [from Fre pluie] : rain'),
#  (173, 'laplipar  [from Fre la plus part] : most  (of)'),
#  (173, 'lapolis  [from Fre p olice] : police'),
#  (173, 'laponp  [from Fre pompe] : pump; fountain'),
#  (173, 'laport  [from Fre porte] : door'),
#  (173, 'lapres  (1) [from Fre presse] : press'),
#  (173, 'lapres  (2) [from Fre preche] : sermon'),
#  (173, 'laprwa  [from Fre proie] : prey  lapryer  [from Fre priere] : prayer'),
#  (174, 'laptitide  [from Fre aptitude] : capability;  skills'),
#  (174, 'lapud  [from Fre poudre] : powder'),
#  (174, 'lar [from Fre art] : art'),
#  (174, 'laraf  [from Fre rafle] : raid'),
#  (174, 'larak  [from Fre arak] : liquor'),
#  (174, 'laral  [from Fre rale] : rattle of the throat'),
#  (174, 'laranzman  [from Fre arrangement] :  arrangement'),
#  (175, 'larap  [from Fre rape] : rasp'),
#  (175, 'larat  [from Fre rate] : spleen'),
#  (175, 'laraz  [from Fre rage] : rage'),
#  (175, 'lareg  [from Fre régle] : rule'),
#  (175, 'large  (larg) [from Fre larguer] : to let out'),
#  (175, 'lari [from Fre rue] : street'),
#  (175, 'larises  [from Fre richesse] : riches; wealth'),
#  (175, 'Larisi  [from Fre Russie] : Russia'),
#  (175, 'larive  [from Fre arrivee] : arrival'),
#  (175, 'larivyer  [from Fre riviere] : river'),
#  (176, 'larmoni  [from Fre harmonie] : harmony'),
#  (176, 'larozwar  [from Fre arrosoir] : watering can'),
#  (176, 'lartik  [from Fre article] : article'),
#  (176, 'lartis  [from Fre artiste] : artist'),
#  (177, 'laru [from Fre roue] : wheel'),
#  (177, 'laruinn  [from Fre ruine] : ruin'),
#  (177, 'larut  [from Fre route] : road'),
#  (177, 'larz [from Fre large] : large'),
#  (177, 'larzan  [from Fre argent] : money'),
#  (177, 'lasal  [from Fre salle] : hall'),
#  (177, 'lasam  [from Fre chambre] : roo m  lasann  [from Fre cendre] : ash'),
#  (177, 'lasans  [from Fre chance] : chance'),
#  (178, 'lasasen  [from Fre assassin] : killer'),
#  (178, 'lasenn  (1) [from Fre chaine] : chain'),
#  (178, 'lasenn  (2) [from Fre scene] : scene'),
#  (178, 'laser  [from Fre chair] : flesh'),
#  (178, 'lasi [from Fre scie] : saw (tool)'),
#  (178, 'lasiet  [from Fre assiette] : plate'),
#  (179, 'lasir  [from Fre cire] : wax'),
#  (179, 'lasos  [from Fre sauce] : sauce'),
#  (179, 'laspe  [from Fre aspect] : aspect'),
#  (179, 'lasup  [from Fre soupe] : soup'),
#  (179, 'lasurs  [from Fre source] : source'),
#  (181, 'latas  [from Fre tache] : task'),
#  (181, 'latelye  [from Fre atelier] : workshop; studio'),
#  (181, 'later  [from Fre terre] : earth'),
#  (181, 'latitid  [from Fre attitude] : attitude'),
#  (181, 'latrup  [from Fre troupe] : team ; group'),
#  (181, 'latwal  [from Fre toile] : fabric'),
#  (181, 'lavaper  [from Fre vapeur] : steam'),
#  (182, 'lavenn  [from Fre veine] : vein'),
#  (182, 'laverite  [from Fre verite] : truth'),
#  (182, 'lavi (2) [from Fre vue] : sight'),
#  (182, 'lavil [from Fre ville] : city'),
#  (182, 'lavyann  [from Fre viande] : meat'),
#  (182, 'lavwa  [from Fre voix] : voice'),
#  (183, 'lazam  [from Fre jambe] : leg'),
#  (183, 'lazistis  [from Fre justice] : justice'),
#  (183, 'lazu [from Fre joue] : cheek'),
#  (183, 'lazurne  [from Fre journee] : daytime'),
#  (183, 'lazwa  [from Fre joie] : happiness'),
#  (183, 'leben  [from  *lé bain from Fre bain] : bath'),
#  (183, 'lebra  [from Fre les bras] : arms'),
#  (184, 'ledan  [from  *lé dent  from Fre dent] : tooth'),
#  (184, 'ledo [from *lé do from  Fre dos] : back'),
#  (184, 'ledub  [from  *lé double from Fre  double] :  double'),
#  (185, 'lefet [from  *lé fait  from Fre fait] : fact'),
#  (185, 'lefwa  [from  *lé foie  from Fre foie] : liver'),
#  (185, 'legim  [from Fre legume] : legumes'),
#  (185, 'legliz  [from Fre egliz] : church'),
#  (185, 'legza men [from Fre examen] : examination'),
#  (185, 'legzanp  [see egzanp] : example'),
#  (186, 'lekonomi  [from Fre economie] : economy'),
#  (186, 'lekontrer  [from *lé contraire from Fre  contraire] : contrary'),
#  (186, 'lekor  [from * lé corps  from Fre corps] :  body'),
#  (187, 'lekors  [from Fre ecorce] : bark'),
#  (187, 'lekritir  [from Fre ecriture] : writing'),
#  (187, 'leksplikasyon  [from Fre explication] :  explanation'),
#  (187, 'lekspozisyon  [from Fre exposition] :  exhibition'),
#  (188, 'lematen  [from  *lé matin  from Fre matin] :  morning'),
#  (188, 'lemer  [from  *lé maire from  Fre maire] :  mayor'),
#  (188, 'lemet  [from  Fre emeute] :  public unrest'),
#  (188, 'lemoman  [from  *lé moment  from Fre  moment] : moment'),
#  (189, 'asosyasyon peyzan = In India you find  peasant associations'),
#  (189, 'lendi  [from Fre lundi] : Monday'),
#  (189, 'lendistri  [from Fre industrie] :  industry'),
#  (190, 'lenpasyans  [from Fre impatience] :  impatience'),
#  (190, 'lenpo  [from Fre impot] : tax'),
#  (190, 'lenportans  [from Fre importance] :  importance'),
#  (190, 'lenpotans  [from Fre impotence] :  impotence'),
#  (190, 'lensek  [from Fre insecte] : insect'),
#  (190, 'lenspekter  [from Fre ins pecteur ] :  inspector'),
#  (191, 'lenstriman  [from Fre instrument] :  instrument'),
#  (191, 'lentere  [from Fre interet] : interest'),
#  (191, 'lenvitasyon  [from Fre invitation] :  invitation'),
#  (191, 'lenwi  [from Fre ennui] : boredom'),
#  (191, 'lenz [from Fre linge]  : clothing'),
#  (193, 'lepor  [from  *lé port  from Fre port] : port'),
#  (193, 'leprev  [from  *lé prev  from Fre preuve] :  proof'),
#  (193, 'lepu [from  *lé pou  from Fre pou] : louse'),
#  (193, 'ler (1) [from Fre heure] : time; when'),
#  (193, 'ler (2) [from Fre aire] : air'),
#  (193, 'lera [from * lé rat  from Fre rat] : rat'),
#  (196, 'lesel [from Fre echelle] : scale'),
#  (196, 'lesid  [from *lé sid from Fre sud] :  south'),
#  (197, 'lesperans  [from Fre esperance] : hope'),
#  (197, 'lespri  [from Fre esprit] : spirit'),
#  (197, 'lestoma  [from Fre estomac] : stomach'),
#  (197, 'lesu [from * lé choux  from Fre choux] :  cabbage'),
#  (199, 'letaz  [from Fre etage] : floor'),
#  (199, 'lete [from Fre ete] : summer'),
#  (199, 'letid  [from Fre etude] : study'),
#  (199, 'letur  [from * lé tour  from Fre tour] :  round'),
#  (199, 'levek  [from Fre eveque] : archbishop'),
#  (199, 'lever  [from  *lé ver  from Fre ver] :  worm'),
#  (199, 'lezann  [from Fre legende] : legend'),
#  (199, 'lezar  [from Fre lezard] : lizard'),
#  (199, 'leze [from Fre leger] : light'),
#  (200, 'liberte  [from Fre  liberte] : liberty'),
#  (200, 'lide [from Fre idee] : idea'),
#  (200, 'likid  [from Fre  liquide] : liquid'),
#  (200, 'liku [from Fre cou] : neck'),
#  (201, 'lili [from Fre lit] : bed'),
#  (201, 'lim [from Fre hymne] : anthem'),
#  (201, 'limem  [from Fre lui -meme] : himself'),
#  (201, 'limur  [from Fre  humour ] : humor'),
#  (201, 'liniver  [from Fre univers] : universe'),
#  (202, 'linyon  [from Fre union] : union'),
#  (202, 'lipye  [from Fre pied] : leg'),
#  (203, 'lisid [from Fre  lucide] : lucid'),
#  (203, 'listerik  [from Fre  hysterie ] : hysteria'),
#  (203, 'listwar  [from Fre histoire] : history'),
#  (203, 'lisyen  [from Fre chien] : dog'),
#  (203, 'lite [from Fre lutter] : to fight'),
#  (204, 'liver  [from Fre hiver] : winter'),
#  (204, 'lizienn  [from Fre  hygiene ] : hygiene'),
#  (204, 'lizinn  [from Fre usine] : plant'),
#  (204, 'lizur  [from Fre jour] : day'),
#  (204, 'lodas  [from Fre audace] : audacity'),
#  (204, 'lof [from Fre offre] : offer'),
#  (204, 'lofans  [from Fre offence] : offence'),
#  (204, 'lokazyon  [from Fre occasion] : occasion'),
#  (204, 'loksidan  [from Fre occident ] :  occident'),
#  (205, 'loksizenn  [from Fre oxygene] : oxygen'),
#  (205, 'lom [from Fre ombre] : shade'),
#  (205, 'lomonn  [from Fre aumone] : alms'),
#  (205, 'lonbraz  [from Fre ombrage] : shadow'),
#  (205, 'loner  [from Fre honneur] : honor'),
#  (205, 'long [from Fre long] : long'),
#  (205, 'Lonn  [from Fre Londres] : London'),
#  (205, 'lontan  [from Fre longtemps] : a long time'),
#  (205, 'loperasyon  [from Fre operation] :  operation'),
#  (205, 'lopinyon  [from Fre opinion] : opinion'),
#  (205, 'lopital  [from Fre hopital] : hospital'),
#  (205, 'lor (1) [from Fre lors] : at the time; in; on;  about'),
#  (207, 'lorgey  [from Fre org ueil] : pride'),
#  (207, 'lortey  [from Fre orteil] : toe'),
#  (207, 'loryan  [from Fre orient] : Orient'),
#  (207, 'losean  [from Fre ocean] : ocean'),
#  (209, 'lye (1) [from Fre lieu] : place'),
#  (209, 'lye (2) [from Fre lier] : to tie'),
#  (211, 'mal (2) [from Fre male] : male'),
#  (211, 'malad  [from Fre malade] : sick'),
#  (212, 'malen  [from Fre malin] : malign; evil'),
#  (212, 'maler  [from Fre malheur] : misfortune'),
#  (214, 'mang  [from Fre mangue] : mango'),
#  (214, 'manga  [from Mal] : morose'),
#  (216, 'mariye  [from Fre marier] : to marry'),
#  (216, 'mars  [from Fre mars] : March'),
#  (216, 'marsan  [from Fre marchand] : merchant;  shop -keeper'),
#  (217, 'maryaz  [from Fre mariage] : marriage'),
#  (217, 'masak  [from Fre massacre] : massacre'),
#  (218, 'maswar  [from Fre machoire] : jaw'),
#  (218, 'matyer  [from Fre matiere] : matter'),
#  (218, 'mazeste  [from Fre majeste] : majesty'),
#  (218, 'mazik  [from Fre magique] : magical'),
#  (218, 'mazinasyon  [from Fre imagination] :  imagination'),
#  (219, 'meb [from Fre meuble] : furniture'),
#  (219, 'meg [from Fre maigre] : meager; thin'),
#  (220, 'melanz  [from Fre mélange] : mix'),
#  (220, 'melanze  (melanz) [from Fre mélanger] : to  mingle'),
#  (221, 'mervey  [from *mérveille from Fre  merveille] : marvel; miracle'),
#  (221, 'merveye  [from *mérveilleux from Fre  merveilleux] : marvelous'),
#  (222, 'mesaz  [from *méssage from Fre message] :  message'),
#  (222, 'met [from Fre métre] : meter'),
#  (222, 'metrize  (metriz) [from Fre maitriser] : to  overcome'),
#  (222, 'metye  [from Fre métier] : job'),
#  (223, 'mezire  [from *mésurer from Fre mesurer] :  to measure'),
#  (223, 'midi  [from Fre midi] : noon'),
#  (224, 'milat  [from Fre mulatre] : mixed -blood'),
#  (224, 'mile [from Fre mulet] : mule'),
#  (224, 'miliye  [from Fre milieu] : middle'),
#  (224, 'miltipliye  [from Fre multiplier] : to  multiply'),
#  (224, 'minisyon  [from Fre munition] :  ammunition'),
#  (224, 'minwit  [from Fre minuit] : midnight'),
#  (225, 'mir (1) [from Fre mur] : wall'),
#  (225, 'mir (2) [from Fre mure] : ripe'),
#  (226, 'misk  [from Fre muscle] : muscle'),
#  (226, 'mistek  [from Eng] : mistake'),
#  (226, 'mister  [from Fre mystere] : mystery'),
#  (227, 'mit [from Fre mythe] : myth'),
#  (227, 'miye  [from Fre muet] : mute; dumb'),
#  (227, 'mizelye r [from Fre museliere] : muzzle'),
#  (228, 'mizisyen  [from Fre musicien] : musician'),
#  (228, 'mo (1) [from Fre mon] : my ; I'),
#  (229, 'mondyal  [from Fre mondia l] : global'),
#  (229, "mo'nn  [from mo + inn] : I’ve"),
#  (229, 'mons  [from Fre monstre] : monster'),
#  (229, 'mont  [from Fre montre] : watch'),
#  (229, 'montany  [from Fre montaigne] :  mountain'),
#  (231,
#   'Bizen lasanble isi prezan, onon  tu bann Morisyen, deklar so sinpati pu  bann abitan Lareynyon = I n the name of  the Mauritians, t he assembly present here  must declare its sympathy for the  inhabitants (of ) Reunion'),
#  (231, 'morso  [from Fre morceau] : morsel'),
#  (231, "mo'si  [from mo + usi] : me too"),
#  (232, 'mu [from Fre mou] : soft'),
#  (232, 'mulen  [from Fre moulin] : mill'),
#  (232, 'mustas  [from Fre moustache] : moustache'),
#  (232, 'muswar  [from Fre mouchoir] :  handkerchief'),
#  (233, 'mwat  [from Fre moite] : moist; sweaty,  sticky'),
#  (233, 'mwayenn  [from Fre moyenne] :  average'),
#  (236, 'natirel  [from Fre naturel] : natural'),
#  (236, 'natirelman  [from Fre naturellement] :  naturally'),
#  (236, 'navir  [from Fre navire] : ship'),
#  (236, 'naze  [from Fre nager] : to swim'),
#  (236, 'ne (1) [from Fre ne] : born'),
#  (237, 'nef (1) [from Fre neuf] : new'),
#  (237, 'nef (2) [from Fre neuf] : nine'),
#  (237, 'neg [from Fre negre] : Negro'),
#  (237, 'nek [from Fre n’est que] : just'),
#  (239, 'ners [from Eng] : nurse'),
#  (239, 'nesans  [from Fre naissance] : birth'),
#  (240, 'nevan  [from Fre neuf ans] : nine years'),
#  (240, 'never  [from Fre neuf heures] : nine hours'),
#  (240, 'nevyem  [from Fre neuvieme] : ninth'),
#  (240, 'ni [from Fre ni ] : (n)either'),
#  (240, 'nyaz  [from Fre nuage] : cloud'),
#  (240, 'noel [from Fre noel] : Christmas'),
#  (242, 'normal  [from Fre normal] : normal; of  course'),
#  (242, 'normalman  [from Fre normalement] :  normally; usually'),
#  (242, 'novam  [from Fre novembre] : Novembre'),
#  (242, 'nu [from Fre nous] : we'),
#  (242, 'nuri [from Fre nourrir] : to nourish'),
#  (242, 'nuritir  [from Fre nourriture] :  nourishment'),
#  (244, 'obligatwar  [from Fre obligatoire] :  obligatory'),
#  (244, 'obligatwarman  [from Fre  obligatoirement] : obligatorily'),
#  (246, 'oktob  [from Fre octobre] : October'),
#  (246, 'okumansman  [from Fre au  commencement] : to start with'),
#  (247, 'omaz  [from Fre hommage] : homage;  respect'),
#  (247, 'omilye  [from Fre au milieu] : in the middle  (of)'),
#  (247, 'onet [from Fre honnete] : honest'),
#  (247, 'onon  [from Fre au nom] : in the name  (of)'),
#  (248, 'onzyem  [from Fre onzieme] : eleventh'),
#  (248, 'operater  [from Fre operateur] :  operator'),
#  (249, 'orizinal  [from Fre original] : original'),
#  (249, 'ot [from Fre haut] : high'),
#  (251, 'pak [from Fre pacte] : pact'),
#  (251, 'pake  [from Fre paquet] : package'),
#  (251, 'pal [from Fre pale] : pale'),
#  (253,
#   'panse  (2) [fro m Fre pencher] : to bend; to  lean  panye  [from Fre panier] : basket'),
#  (253, 'papye  [from Fre papier] : paper'),
#  (253, 'parapor  [from Fre par rapport] : compared'),
#  (253, 'paravan  [from Fre paravent] : screen'),
#  (259, 'paz [from Fre page] : page'),
#  (259, 'pe [see ape] :  verbal aspect'),
#  (260, 'penso  [from Fre pinceau] : brush'),
#  (260, 'pent  [from Fre peintre] : painter'),
#  (261, 'per (2) [from Fre paire] : pair'),
#  (261, 'perdi  [from Fre perdu] : lost; wasted'),
#  (263, 'pese [from Fre peche] : sin; guilt'),
#  (263, 'peser  [from Fre pecheur] : fisherman'),
#  (263, 'pete (1) (pet) [from Fre peter] : to fart'),
#  (263, 'peye  [from Fre payer] : to pay'),
#  (263, 'peyzan  [from Fre paysan ] : peasant'),
#  (264, 'piez [from Fre piege] : trap  pikan  [from Fre piquant] : thorn'),
#  (265, 'pir (1) [from Fre pire] : worse'),
#  (265, 'pir (2) [from Fre pure] : pure'),
#  (265, 'pirman  [from Fre purement] : purely'),
#  (266, 'pla [from Fre plat] : plate'),
#  (266, 'plake  [from Fre plaquer] : to cov er'),
#  (268, 'plise  (2) [from Fre eplucher] : to peel'),
#  (268, 'plito  [from Fre plutot] : rather'),
#  (270, 'popilasyon  [from Fre population] :  population'),
#  (270, 'pos [from Fre poche] : pocket'),
#  (272, 'prefas  [from Fre preface] : preface'),
#  (272, 'prefere  [from Fre preferer] : to prefer'),
#  (275, 'promete  (promet)  [from Fre promettre] : to  promise'),
#  (275, 'promne  [from Fre promener] : to walk'),
#  (278, 'pwant  [from Fre pointe] : point, tip'),
#  (278, 'pwason  [from Fre poisson] : fish'),
#  (281, 'ranplase  (ranplas) [from Fre remplacer] :  to replace'),
#  (281, 'ranpli  [from Fre remplir] : to fill'),
#  (286,
#   'regleman  [from Fre réglement] : regulation;  rule  regrete  [from *régretter  from Fre  regretter] : to regret'),
#  (286,
#   'rekeyi  [from *récueillir from Fre  recueillir] : to gather; to pick up'),
#  (286, 'rekolte  [from Fre récolter] : to harvest'),
#  (288, 'relanse  [see lanse] : to launch  again; to  restart'),
#  (288, 'relizyon  [from *réligio n from Fre religion] :  religion'),
#  (288,
#   'remarke  (remark) [from *rémarquer from  Fre remarquer] : to remark; to notice'),
#  (292, 'reset  [from *récette from Fre recette] :  receipt; revenue'),
#  (292, 'resevwa  [from *récevoir  from Fre  recevoir] : to receive'),
#  (296, 'rezonman  [from Fre raisonnement] :  reasoning'),
#  (296, 'rezud  [from Fre résoudre] : to  resolve'),
#  (297, 'rid [from Fre rude] : rude'),
#  (297, 'rimer  [from Fre rumeur] : rumor'),
#  (298, 'robo  [from Fre robot] : traffic light'),
#  (298, 'rode  (rod) [from Fre roder] : to seek'),
#  (298, 'ron [from Fre rond] : round'),
#  (298, 'ros [from Fre roche] :  rock'),
#  (302, 'sal [from Fre sale] : dirty'),
#  (302, 'salam  [from Hin] : hello'),
#  (302,
#   'saler  [from Fre salaire] : sal ary  sali [from Fre salut] : salute; greeting'),
#  (302, 'saliye  [from Fre saluer] : to greet'),
#  (302, 'samaye  [from Fre chamailler] : to quarrel'),
#  (302, 'samdi  [from Fre samedi] : Saturday'),
#  (303, 'samo  [from Fre chameau] : camel'),
#  (303, 'san (1) [from Fre sans] : without'),
#  (304, 'sanpinyon  [from Fre champignon] :  mushroom'),
#  (304, 'sanpyon  [from Fre champion] : champion'),
#  (304, 'sans [from Fre chance] : chance'),
#  (305, 'sanson  [from Fre chanson] : song'),
#  (305, 'sant [from Fre centre] : center'),
#  (305, 'santaz  [from Fre chantage] : blackmail'),
#  (305, 'sante  [from Fre chanter] : to sing'),
#  (307, 'sarbon  [from Fre charbon] : carbon; coal'),
#  (307, 'saret  [from Fre charrette] : cart'),
#  (308,
#   'sarite  [from Fre charite] : charit y  sarm  [from Fre charme] : charm'),
#  (308, 'sarony  [from Fre charogne] : cadaver'),
#  (308, 'sarye  [from Fre charrier] : to carry  away'),
#  (309, 'sat [from Fre chat] : cat'),
#  (309, 'satisfe  [from Fre satisfait] : satisfied'),
#  (310, 'sayi [from Fre chahut] : noise'),
#  (310, 'sayt [from Eng] : site'),
#  (311, 'sef [from Fre chef] : chief'),
#  (311, 'sega [from Ban] : a dance'),
#  (312, 'sek (3) [from Fre cheque] : cheque'),
#  (312, 'seki [from Fre ce qui] : what’s'),
#  (314, 'semiz  [from Fre chemise] : shirt'),
#  (314, 'sen [from Fre saint] : saint'),
#  (314, 'sendika  [from Fre  syndicat] : trade union'),
#  (314, 'seni [from Fre chenille] : caterpillar'),
#  (315, 'senpati  [from Fre  sympathie] : sympathy'),
#  (315, 'senser  [from Fre sincere] : sincere'),
#  (315, 'separe  (separ) [from Fre s eparer] : to  separate'),
#  (315, 'septam  [from Fre septembre] : Septembre'),
#  (316, 'ser (2) [from Fre cher] : dear'),
#  (316, 'sere (ser) [from Fre serrer] : to lock'),
#  (316, 'serk [from Fre cercle] : circle'),
#  (316, 'serye  [from Fre serieux] : serious'),
#  (317, 'sertenn  [from Fre certaine] : certain'),
#  (317, 'sertennman  [from Fre certainement] :  certainly'),
#  (317, 'serti  [from Fre sert] : serve'),
#  (317, 'servo  [from Fre cerveau] : brain'),
#  (317, 'set [from Fre sept] : seven'),
#  (318,
#   'setadir  [from Fre c’est a dire] : that is; so to  say  sever  [from Fre severe] : severe'),
#  (319, 'sez (2) [from Fre seize] : sixteen'),
#  (319, 'si [from Fre si] : if'),
#  (320, 'sik [from Fre chic] : pretty; teasing'),
#  (320, 'sikane  [from Fre chicaner] : to harass'),
#  (320,
#   'siklonn  [from Fre cyclone] : Siklonn form  parti dan bann risk = Cyclones constitute a  part of the risks'),
#  (322, 'sintir  [from Fre ceinture] : belt'),
#  (322, 'sinye  (siny) [from Fre signer] : to sign'),
#  (322, 'sipa [from Fre sais pas] : who knows'),
#  (322, 'sipor  [from Fre su pport] : support'),
#  (322, 'sir [from Fre sure] : sure'),
#  (323, 'sirkilasyon  [from Fre circulation]  :  cirdulation; traffic'),
#  (323, 'sirkile  [from Fre circuler] : to cirdulate'),
#  (323, 'sirman  [from Fre surement] : sure'),
#  (323, 'sirsarz  [from Fre su rcharge] : surcharge'),
#  (323, 'sirtu  [from Fre surtout] : especi ally'),
#  (324, 'siseptib  [from Fre  susceptible] : susceptible'),
#  (324, 'sispek  [from Fre su spect] : suspect'),
#  (324, 'sistem  [from Fre  systeme] : system'),
#  (324, 'sitan  [from Fre si tant] : so'),
#  (325, 'sitye  [from Fre situer] : to be located'),
#  (325, 'sive [from Fre cheveu] : hair'),
#  (325, 'siyuple  [from Fre s’il vous plait] : please'),
#  (325, 'sizan [from Fre six ans] : six years'),
#  (325, 'sizer  [from Fre six heures] : six hours'),
#  (325, 'sizo [from Fre ciseau] : chisel'),
#  (325, 'sizyem  [from Fre sixieme] : sixth'),
#  (326, 'skiltir  [from Fre sculpture] : sculpture'),
#  (326, 'so (1) [from Fre son] : his'),
#  (327, 'somer  [from Fre chomeur] : unemployed'),
#  (327, 'somey  [from Fre sommeil] : sleep'),
#  (328, 'son [from Fre son] : sound'),
#  (328, 'sone  [from Fre sonner] : to so und'),
#  (328, 'sopinn  [from Fre chopine] : jug'),
#  (328, 'sori [from Eng] : sorry'),
#  (328, 'soset  [from Fre chaussette] : sto cking'),
#  (328, 'sosyete  [from Fre societe] : society'),
#  (329, 'spektak  [from Fre spectacle] : spectacle;  sight'),
#  (329, 'spesyal  [from Fre special] : special'),
#  (331, 'sulye  [from Fre soulier] : shoe'),
#  (331, 'sup [from Fre souple] : supple'),
#  (331, 'supir  [from Fre soupir] : sigh'),
#  (331, 'supire  [from Fre soupirer] : to sigh'),
#  (331, 'surd  [from Fre sourd] : deaf'),
#  (331, 'suri [from *sourir from Fre sourire] : to  smile'),
#  (331, 'surir  [from Fre sourir] : smile'),
#  (332, 'sutyen  [from Fre soutien] : support'),
#  (332, 'suval  [from Fre cheval] : horse'),
#  (332, 'suvan  [from Fre souvent]  : often'),
#  (333,
#   'swanye  (swayn) [from Fre soigner] : to  care  swasant  [from Fre soixante] : sixty'),
#  (334, 'syantifik  [from Fre scientifique] : scientific'),
#  (334, 'syantis  [from Eng] : scientist'),
#  (336, 'tandans  [from Fre tendence] : tendency'),
#  (336, 'tandi  [from Fre tandis] : while'),
#  (336, 'tandres  [from Fre tendresse] : tenderness'),
#  (337, 'tann  (1) [from Fre tendre] : tender'),
#  (337, 'tann  (2) [from Fre entendre] : to hear'),
#  (337, 'tansyon  [from Fre attention] : attention'),
#  (337, 'tantasyon  [from Fre tentation] : temptation'),
#  (339, 'telefonn  [from Fre telephone] : telephone'),
#  (339, 'telman  [from Fre tellement] : so'),
#  (339, 'tem (1) [from Fre theme] : theme; subject'),
#  (339, 'tem (1) [from Fre timbre] : stamp'),
#  (339, 'temwan  [from Fre temoin] : witness'),
#  (340, 'tenas  [from Fre tenace] : tenacious'),
#  (340, 'tenye  (teyn) [from Fre eteindre] : to  extinguish'),
#  (340, 'terib  [from Fre terrible] : terrible'),
#  (340, 'tes [from Fre test] : test'),
#  (340, 'ter [from Fre terre] : earth'),
#  (341, 'tifi [from Fre petite fille] : girl'),
#  (341, 'tig [from Fre tigre] : tiger'),
#  (342, 'tip [from Fre type] : type'),
#  (342, 'tipik  [from Fre typique] : typical'),
#  (342, 'tire (1) (tir) [from Fre tirer] : to draw'),
#  (343, 'tit [from Fre titre] : title'),
#  (343, 'tiye (tiy) [from Fre tuer] : to kill'),
#  (343, 'tiyo [from Fre tuyau] : pipe'),
#  (343, 'to [from Fre ton] : you(r)'),
#  (345, 'tonbo  [from Fre tombeau] : tomb'),
#  (345, "to'nn  [from to + inn] : you've"),
#  (345, 'tradir [from Fre traduire] : to translate'),
#  (345, 'trak [from Fre tract] : leaflet'),
#  (348, 'travayer  [from Fre travailleur] : worker'),
#  (348, 'traverse  (travers) [from Fre traverser] : to  cross'),
#  (349, 'trazik  [from Fre tragique] : tragic'),
#  (349, 'tren [from Fre train] : train'),
#  (349, 'trezyem  [from Fre treizieme] : thirteenth'),
#  (349, 'tris [from Fre triste] : sad'),
#  (351, 'trwazan  [from Fre trois ans] : three years'),
#  (351, 'trwazer  [from Fre trois heures] : three  hours'),
#  (356, 'urdi [from Fre ourdir] : to spin; to weave'),
#  (356, 'urit [from Mal] : octopus'),
#  (357, 'ut [from Fre aout] : August'),
#  (357, 'uver  [from Fre ouvert] : open'),
#  (360, 'vas [from Fre vache] : cow'),
#  (360, 've [from Fre voeu] : vow'),
#  (361, 'venker  [from Fre vainqueur] : victor;  winner'),
#  (361, 'ventenn  [from Fre vingt un] : twenty one'),
#  (361, 'ventwit  [from Fre vingt huit] : twenty eight'),
#  (361, 'ver (1) [from Fre vers] : towards'),
#  (363, 'viger  [from Fre  vigueur] : vigor'),
#  (363, 'vilaz  [from Fre village] : village'),
#  (363, 'vilger  [from Fre  vulgaire] : vulgar'),
#  (363, 'vineg  [from Fre  vinaigre] : vinager'),
#  (363, 'vini (1) (vinn) [from Fre venir] : to come'),
#  (364,
#   'violan  [from Fre violent] : violen t  violans  [from Fre violence] : violence'),
#  (364, 'vire [from Fre virer] : to turn'),
#  (367, 'vokabiler  [from Fre vocabulaire] :  vocabulary'),
#  (367, 'vol [from Fre vol] : theft'),
#  (367, 'voler  [from Fre voleur] : thief'),
#  (367, 'volim  [from Fre  volume] : volume'),
#  (367, 'vomi  [from Fre vomir] : to vomit'),
#  (367, 'votur  [from Fre vautour] : vulture'),
#  (367, 'vre [from Fre vrai] : true'),
#  (368, 'vreman  [from Fre vraiement] : truly'),
#  (368, 'vremem  [from Fre vrai meme] : true'),
#  (368, 'vwatir  [from Fre voiture] : vehicle'),
#  (368, 'vwayaz  [from Fre voyage] : trip'),
#  (369, 'vwazen  [from Fre voisin] : neighbor'),
#  (369, 'vwazinaz  [from Fre voisinage] :  neighborhood'),
#  (373, 'Z  zadi [from Fre jadis] : long time ago'),
#  (373, 'zafer  [from Fre affaire] : affair'),
#  (373, 'zalon  [from Fre jalon] : stake'),
#  (373, 'zalu [from Fre jaloux] : jealous'),
#  (373, 'zaluzi  [from Fre jalousie] : jealousy'),
#  (373, 'zame  [from Fre jamais] : never'),
#  (374, 'zameriken  [from Fre americain] :  American'),
#  (374, 'zan [from Fre gens] : people'),
#  (374, 'zanfan  [from Fre enfant] : child'),
#  (374, 'zangi  [from Fre anguille] : eel'),
#  (374, 'zanimo  [from Fre animaux] : animal'),
#  (374, 'zanti  [from Fre gentil] : kind'),
#  (374, 'zantyes  [from Fre gentillesse] : kindness'),
#  (375, 'zanvye  [from Fre janvier] : January'),
#  (375, 'zape  [from Fre  japper ] : to yelp'),
#  (375, 'zar [from Fre genre] : genre'),
#  (375, 'zarb  [from Fre arbre] : tree'),
#  (375, 'zarden  [from Fre jardin] : garden'),
#  (375, 'zarenye  [from Fre araignee] : spider'),
#  (375, 'zarm  [from Fre arme] : arm; weapon'),
#  (375, 'zavoka  [from Fre avocat] : avocado'),
#  (375, 'zean  [from Fre geant] : giant'),
#  (375, 'zedi [from Fre jeudi] : Thursday'),
#  (377, 'zele [from Fre geler] : to freeze'),
#  (377, 'zelev  [from Fre eleve] : pupil'),
#  (377, 'zelvaz  [from Fre elevage] : husbandry'),
#  (377, 'zenerasyon  [from Fre generation] :  generation'),
#  (377, 'zenere  [from Fre genereux] : generous'),
#  (378, 'zenerozite  [from Fre generosite] :  generosity'),
#  (378, 'zenn  [from Fre jeune] : young'),
#  (379, 'zepeng  [from Fre epingle] : pin'),
#  (379, 'zepinar  [from Fre epinard] : spinach'),
#  (379, 'zepinn  [from Fre epine] : thorn'),
#  (379, 'zepis [from Fre epice] : spice'),
#  (379, 'zepol  [from Fre epaule] : shoulder'),
#  (379, 'zerb  (1) [from Fre herbes] : herb'),
#  (380, 'zeye [from Fre  oeillet ] : carnation'),
#  (380, 'Zezi [from Fre Jesus] : Jesus'),
#  (380, 'zi [from Fre jus] : juice'),
#  (380, 'zibie  [from Fre gibier] : game; wild'),
#  (380, 'zil [from Fre ile] : island'),
#  (381, 'zimo  [from Fre  jumeau] : twin'),
#  (381, 'zis [from Fre juste] : just'),
#  (382, 'ziz [from Fre juge] : judge'),
#  (382, 'zize (ziz) [from Fre juger] : to judge'),
#  (382, 'zizeman  [from Fre jugement] : judgement'),
#  (382, 'zo [from Fre os] : bone'),
#  (382, 'zoli [from Fre joli] : nice'),
#  (383, 'zong  [from Fre ongle] : nail'),
#  (383, 'zonn  [from Fre jaune] : yellow'),
#  (383, 'zonyon  [from Fre oignon] : onion'),
#  (383, 'zordi  [from Fre aujourd’hui] : today'),
#  (383, 'zoze [from Fre  jauger ] : to gauge'),
#  (383, 'zozo  [from Fre oiseau] : bird'),
#  (384, 'zurnal  [from Fre journal] : newspaper'),
#  (384, 'zurnalis  [from Fre journaliste] :  newspaperman'),
#  (384, 'zuti [from Fre outil]  : tool'),
#  (384, 'zuvrye  [from Fre ouvrier] : worker'),
#  (384, 'zuzu  [from Fre jouet] : toy'),
#  (384, 'zwa [from Fre oie] : goose'),
#  (384, 'zwann  [from Fre joindre] : to join; to meet'),
#  (385, 'zwaye  [from Fre joyeux] : joyous'),
#  (385, 'zwe (1) [from Fre jouer] : to play'),
#  (385, 'zwin  [from Fre juin] : June'),
#  (385, 'zwit [from Fre huitre] : oyster')]

# %%
all_definitions = [x[1] for x in clean_word_def_list] + [x[1] for x in single_bkt_list]

# %%
import re

def remove_brackets(text):
    # Pattern to find brackets and content within
    pattern = r'\[[^]]*\]|\([^)]*\)'

    # Use re.sub to replace found patterns with an empty string
    result = re.sub(pattern, '', text)

    return result.replace('  ',' ')

# %%
all_definitions.pop(0)
all_definitions.insert(0,'abandone (abandon) [from Fre abandonner] : to abandon')

# %%
cleaned_list = [remove_brackets(item) for item in all_definitions]

# %%
def convert_list(lst,sep):
    # Initialize empty list to store converted items
    converted_lst = []
    triage_l = []

    # Loop through items in original list
    for item in lst:
        # Split item into input and target
        if item.count(':')==1:
            input_str, target_str = item.split(sep)
            # Remove leading/trailing whitespace and strip input string of any brackets
            input_str = input_str.strip().strip('[]()')
            target_str = target_str.strip()
            # Create dictionary with input and target strings
            item_dict = {'input': input_str, 'target': target_str}
            # Add dictionary to converted list
            converted_lst.append(item_dict)
        else:
            triage_l.append(item)

    return converted_lst,triage_l

# Apply function to list
export_json,cleaner_triage_defs = convert_list(cleaned_list,':')

# %%
# import json
# with open('dict1.json', 'w') as f:
#     for item in export_json:
#         # Write dictionary to file on new line
#         f.write(json.dumps(item) + '\n')

# %% [markdown]
# ### cr_en bitext list

# %%
cr_en_bitext_list
# Out:
# [(1,
#   ' Abbreviations  \nAra = Arabic  \nBan = Bantu  \nEng = English  \nFre = French  \nHin = Hindi  \nMal = Malagasy  \nredupl'),
#  (1, ' = reduplication  \n \n \n \n \n \n \n'),
#  (2,
#   ' Akoz samem, \nler mo ti ena sizan mo ti abandon \nposibilite vinn enn gran pent = Because \n(of) that, when I was six years old I \nmissed the  chance to become a great \npainter'),
#  (2, '  Mo finn abandon li tusel lakaz = I \nleft him alone at home'),
#  (2, " Mo'nn seye me abba = I've \ntried but in vain"),
#  (2, '  So \nabitan zot katorz = Its inhab itants number \nfourteen'),
#  (2, ' \nDezyem  planet la ti abite par enn vantar ='),
#  (3,
#   '  Maladi \nla ti abor, me lekipaz pa finn deklar nanye \n= Disease (went) on board, but the crew \ndidn’t declare anything'),
#  (3,
#   ' Malgre \nso puvwar absoli, li ti bon = In spite of his \nabsolute power, he was good'),
#  (3, ' \nAbsans konpetisyon = Absence (of) \ncompetition'),
#  (3, ' Absans predater = Absence \n(of) predators'),
#  (3,
#   '  Bann \ndimunn rod solisyon absird,  parfwa makab \n= Many people seek absurd, sometimes \nmacabre solutions'),
#  (4,
#   ' \nNu kapav truve isi absirdite sa laranzman \nla = We can find here the absurdity (of) \nthis arrangement'),
#  (4,
#   ' E nn bato inn return Moris dan \nlanwit samdi adimans = A ship returned to \nMauritius Saturday night'),
#  (4, ' \nSe pu saliye mo bann admirater = This is \nto greet my admirers'),
#  (4,
#   ' Pli tar li tir mo muton dan so pos \nek kumans admir so trezor = Later he \npulled my sheep from his pocket and \nstarted to admire his treasure'),
#  (4, ' Zame li finn \nadmir enn zetol = He has never admired a \nstar'),
#  (4, '  Mo avway zot tren agos ek adrwat ='),
#  (5, ' Mo pa \nkasiet mo ti agase = I didn’t hide my \nannoyance'),
#  (5,
#   '  Mo \navway zot tren agos ek adrwat = I dispatch \ntheir trains to the left and to the right'),
#  (5,
#   '  Lerla li suy so fron ar enn \nmuswar akaro ruz = Then he wiped his \nforehead with a red -checkered \nhandkerchief'),
#  (5, ' Lerla mo \nferm li akle dan enn tirwar = Then I lock it \nin a drawer'),
#  (6,
#   ' Si nu \nmet sa dimunn la enn akote lot  kuma dan \nmiting piblik = If we array these people \nside by side like in a public meeting'),
#  (6,
#   ' \nAkoz samem, ler mo ti ena sizan mo ti \nabandon posibilite vinn enn gran pent = \nBecause (of) that, when I was six years \nold I missed the chance to become a great \npainter'),
#  (6,
#   ' Me personn pa ti kwar li akoz so \nlabiyman tirk = But nobody believed him \ndue to his Turkish apparel'),
#  (6,
#   ' \nBizen aksepte zeografi ti finn byen ed \nmwa = The need to accept geog raphy \nhelped me a lot'),
#  (6, ' Aksepte mo santiman \nrespe = Accept my feelings (of) respect'),
#  (6,
#   ' Mo ti \nbizen ziz so aksyon, pa so parol = I should \nhave judged his actions, not his sentences'),
#  (7,
#   '  Li kuman s \npar enn analiz byen eksplike sityasyon \naktyel = He starts with a well -explained \nanalysis (of) the actual situation'),
#  (7,
#   ' Mo \npu fer li sote akut marto = I could make it \nundone with a blow (of a) hammer'),
#  (7,
#   ' Ala kifer mo \nti pe viv tusel san vre kominikasyon ar \nlezot = So I live all alone without true \ncommunication with others'),
#  (7, ' Ala kimanyer \nmo ti zwann li = This is how I met him'),
#  (7, ' \nAla u zoli la = How beautiful you are'),
#  (7, '  Ala \nmo sekre = Here is my s ecret'),
#  (7,
#   '  Alafwa enn repons progresis ek \nmoral anfaver enn lasyans ki kapav rezud \nenn parti nu maler =  At the same time, a \nprogressive and moral reaction in favor \n(of) a science that can offer a solution to a \npart of our troubles'),
#  (8,
#   ' Senkyem zur sekre dan so lavi ti \nmont alasirfas = The fifth day the secret in \nhis life was revealed'),
#  (8, ' Kan lot \nbis ale = When does another bus go '),
#  (8,
#   ' Dan \navyon mo finn al buku landrwa dan lemon \n= In the airplane I went to many places in \nthe world'),
#  (8,
#   ' Si enn amerikin kapav surti \nLamerik al Lafrans dan enn minit li pu \ntruv soley kuse = If an American could \nleave America (and) go to France in a \nminute, he m ight see the sunset'),
#  (8, ' Get soley \nal dormi = Watch the sun set'),
#  (8, '  \nale (2) : Li pa ti gayn enn ale = He still \nwasn’t satisfied'),
#  (8,
#   '  \nalerman  : Alerman nu asper kan mem ki \nfatalite napa pu tus sak fami opwen ki zot \nnom pu diminye net = Still, we hope the \ndeaths do not  affect each family to the \npoint that their numbers would'),
#  (9,
#   '  Alerman komers ilegal mendev \nla ti pe fer fut ek tu sa bann obligasyon \nsaniter = At any rate, the illegal work -\nforce trade ignored all sanitary rules'),
#  (9,
#   ' \nAlerman bann pov, bann pret, bann dokter \nfinn res dan lavil = At any rate, poor \npeople, priests, doctors stayed in the city'),
#  (9,
#   ' \nAlerman so travay la ti enn fiasko \nkomersyal konple = Still, his work was a \ncomplete commercial failure'),
#  (9,
#   ' Alerman li ti \nenn militer, me dabor enn lartis = Still, he \nwas a soldier, but first an artist'),
#  (9, ' Li ti \nmari alert = It was very coquettish'),
#  (9,
#   '  Sak fwa li alim so lanpader, se vadir \nenn zetol ki pe ne = Each time he lights \nhis street lamp, it’s as if a star was born'),
#  (9, ' \nMo dibut, li alonze = I’m standing, he’s \nlying'),
#  (10, ' Alor les mo \nsanz dedikas la = Then let me change that \ndedication'),
#  (10,
#   ' Alor dir mwa kimanyer mo ti \nbonom pa ti pa ret perdi sime, fatige, swaf \nusa per = Then tell me how come my little \nfriend doesn’t seem to be lost, tired, \nthirsty or scared'),
#  (10,
#   ' Alor to finn sap dan \nlesyel, tonbe = Then you came from the \nsky, fallen'),
#  (10, " Alor twa'si to surti dan lesyel \n= Then you also come f rom the sky"),
#  (10, ' Alor \nmo refer mo promye desen = Then I \nremade my first drawing'),
#  (10, ' Pentir \nalwil = Oil painting'),
#  (10,
#   '  Ena enn ti pursantaz  dimunn \nki ankor gard lespwar ki tu kapav \namelyore = There’s a small percentage (of) \npeople who still have hopes that \neverything could turn to the better'),
#  (11,
#   ' So parol ti ekler mister ki ti \nfinn amenn li isi  = His words shed light to \nthe mystery (as to) what took him here'),
#  (11, " \nKot to'le amenn mo muton = Where do \nyou want to take my sheep"),
#  (11, ' Amenn mwa \nget soley kuse = Take me to watch the \nsunset'),
#  (11,
#   ' Bann gran miltinasyonal, amizir zot \nglobalize, devor ti konpanyi la = The big \nmultinationals, to the extent they globalize, \ndevour the small companies'),
#  (11,
#   ' \nTanzantan to va kondan li amor = From \ntime to time y ou’re going to condemn it to \ndeath'),
#  (11,
#   ' Astronon la ti refer \nprezantasyon so dekuvert an 1920 = This \nastronomer repeated the presentation (of)'),
#  (12, '  Zordi leswar pu fer \nenn an = Tonight it will be one year'),
#  (12, ' Ti ena de volkan anaktivite = \nThere were two volcanoes in activity'),
#  (12, ' Les mo analiz bayman = Let me \nanalyze yawning'),
#  (12,
#   '  Pu ki nu kon pran tu sa nuvo \ndevlopman la, anu return enpe anaryer \n= To understand all these new \ndevelopments, let’s go back a bit'),
#  (12,
#   ' \nMo zet li anler li tom anba, mo zet li anba \nli mont anler = I throw it in the air, it falls \ndown, I throw it down, it rises in the \nair'),
#  (12, ' Mo la anba pye pom = I’m underneath \nthe apple tree '),
#  (13, ' problem anbadinaz = He takes my \nproblem lightly'),
#  (13, ' Mo pe nom twa anbasader = \nI appoint you (as) ambassador'),
#  (13,
#   '  Bato lavaper la finn al Mozanbik \npu anbos travayer laba = The steam -boat \nwent to Mocam bique to recruit workers \nthere'),
#  (13,
#   ' Mo \nfinn truv enn zoli lakaz anbrik roz = I saw \na nice pink brick house'),
#  (13,
#   ' Me malsans pu \nmwa, mo pa konn get muton andan kes = \nBut I’m unfortunately unable to see the \nsheep within the box'),
#  (14, ' To fler pa andanze = Your flower is \nnot in danger'),
#  (14,
#   '  Mo fler andanze pu fonn, \ndisparet = My flower is in danger (of) \ndisappearing'),
#  (14, ' Enn espes andemik = A native \nspecies'),
#  (14, ' Li tir latet andeor = It pushes its \nhead outwards'),
#  (14,
#   '  Byen sir, li pena otan \nlafors andeo r Lasanble Nasyonal ki li ena \nandan = Of course, he doesn’t have so \nmuch power outside (of) the National \nAssembly as he has within'),
#  (14,
#   ' L i \nanaliz sa bidze la andetay = He analyses \nthis budget  in detail'),
#  (14, '  Nu \nandrwa dimann = We have the right to ask'),
#  (15,
#   ' Dipi plizir \nmilyon bann ane bann fler fabrik pikan = \nThe flowers have produced thorns for \nmillions of years'),
#  (15,
#   ' Alafwa enn repons progresis ek \nmoral anfaver enn lasyans ki kapav rezud \nenn parti nu maler =  At the same time, a \nprogressive and moral reaction in favor \n(of) a science that can offer a solution to a \npart of our troubles'),
#  (15, ' Anfen enn \nsibaltern = Finally a subject'),
#  (15,
#   '  Li ti marse \natraver laplen ros ek lanez, ek anfen li ti \ndekuver enn larut = He walked across \nplains (of) rock and snow, and finally he \ndiscovered a road'),
#  (16, '  Tu \nbann zetol anfler = All the stars \nare blossoming '),
#  (16,
#   '  Enn ti \nliv bileng angle ek kreol = A bilingual \nbooklet in English and Creole'),
#  (16, '  Anka \nenn nuvo epidemi = In case (of) a new \nepidemics'),
#  (16,
#   '  Ler \nto revini pu nu dir salan, mo pu donn twa \nenn sekre ankado = When you return to \nsay farewell, I give you a secret, free of \ncharge'),
#  (16, ' Met ankestyon = To question'),
#  (16, ' Ler \nmo ankoler mo vomi dife = When I’m \nangry I vomit fire'),
#  (17,
#   '  Li ankonfli avek so vye alye = \nHe’s  in conflict with his old ally'),
#  (17,
#   ' Mo ankor \nkwar pa fasil ar zot = I still think it’s not \neasy with them'),
#  (17, " Mo pa'nkor vizit partu = I \nhaven’t visited every where yet"),
#  (17, ' Li ti dir \nankor de trwa mo = He said a few words \nmore'),
#  (17,
#   '  Diskur pibliye pu premye fwa dan \nenn liv separe dan versyon orizinal \nankreol anut = Discourse published the \nfirst time in a separate book in the orig inal \nversion in Creole in August'),
#  (18, ' ankuraz lisansiman = The government \ncontinues to encourage layoffs'),
#  (18,
#   ' \nBizen fer pu tus so nam anlarm = It’s  \nnecessary to touch his soul in tears'),
#  (18,
#   ' Mo \nzet li anler li tom anba, mo zet li anba li \nmont anler = I throw it in the air, it falls \ndown, I throw it down, it rises in the air'),
#  (18,
#   ' \nLi ti finn donn valer bann parol anler =  \nFinally he took the unimportant sentences \nseriously'),
#  (18, '  Mo al chake anliberte = I go and \nwalk about as I please'),
#  (18, ' Sa fler la li ti byen \nanmani = This flower was very \ncomplicated'),
#  (18, ' Mo finn ne anmemtan ki \nsoley = I was born the same time as the'),
#  (19,
#   ' Li ti posib anmemtan fidel ek pares = \nIt’s possible to be faithful and lazy  at the \nsame time '),
#  (19,
#   ' Li ti vir deryer anmemtan me \nli pa ti truv person n = He turned around at \nthe same time but he didn’t see anybody'),
#  (19,
#   '  Lagazet ti pe anons ki nek dan \nsa trwa dernye zur, bann dese inn ariv enn \nsif ki plis ki lidub moyenn bann dese ki ti \nena avan la = The paper announc ed that \njust in the last three days, the deaths \nreached a number that was more than \ntwice that before'),
#  (19,
#   '  Li ti turn \notur so sevi kuma enn brasle anor = It \ntwisted  around his ankle like a golden \nbracelet '),
#  (19,
#   ' Ti fini ariv wityem zur dipi ki \nmo ti tom anpann = Then came the eighth'),
#  (20, ' Tu \nbiznes anpann = All business (activities) \nbroke down'),
#  (20,
#   '  Li ti \nveritab promye minis anpratik ant 2000 ek \n2005 = P ractically he was  the real prime \nminister between 2000 and 2005'),
#  (20,
#   '  Problem ladrog pe vinn plis \nrepandi, ek rezilta ki vol ek brakaz pe \ntrakas dimunn anpermanans = The drog \nproblem is spreading, and the result is that \ntheft and burglary harass the people all the \ntime'),
#  (20,
#   ' Tanka li, nek li pe al anpersonn \ndan tu bann lopital, li ti pe nek vizit bann \nlanbilans = As to him, only he went \npersonally to all the hospitals, only he \nvisited all the ambulances'),
#  (21, '  Mo pa ti pu kapav anpes sa = I \ncouldn’t prevent it'),
#  (21,
#   '  Tudswit, tu bann dimunn ki ti \nprezan finn donn so kontribisyon anplas \nmem = Immediately, everybody present \nmade his contribution on site '),
#  (21, ' Tanka li, li \nfinn res anplas = As to him, he stayed put'),
#  (21, '  Anplen \nzur = In full daytime'),
#  (21, ' \nAnplis mo ena enn fler = In addition I \nhave a flower'),
#  (21, ' Anplis mo pu donn twa enn \nkado = In addition I give you a gift'),
#  (22,
#   ' Si kikenn anpromye \ngayn enn lide, li deklar li, li patant li = If \nsomebody gets an idea at first, he declares  \nit, he patents it'),
#  (22,
#   ' Li ti \nule atupri sirviv sa kriz la e surti anrisi \napre = He wanted to survive this crisis at \nany price and enrich himself afterwards'),
#  (22, ' Zot \nturn anron = They’re revolving around'),
#  (22,
#   ' \nAkote danpi la ti ena enn vye miray ros \nanruinn = Near the well there was an old \nstone wall in ruins'),
#  (22,
#   ' Mo \nde ti bonom mars  ansam, sak enn so tur \ndivan = My two little chaps walk together,'),
#  (23,
#   ' Mazine ki \navan invansyon elektrisite, ti ena, lor tu \nbann kontinan met ansam, enn larme = \nImagine that before the invention (of) \nelectricity, there was, on al l the continents \nput together, an army'),
#  (23,
#   '  Zot \npa kapav fer li ansekre non pli =  They \ncan’t do it in secret any more '),
#  (23, ' \nAnswit to ti riye tomem = Afterwards you \nlaughed yourself'),
#  (23,
#   ' Lager ant \nmuton ek fler pa serye = The war between \nsheep and flowers is not serious '),
#  (24,
#   ' = Slowly it disappeared among the rocks \nwith a slight metallic noise'),
#  (24,
#   ' Li  ti rekrite \nantan ki profeser desen = He was recruited \nas teacher (of) drawing'),
#  (24,
#   ' Li finn kwar dan \nso misyon antan ki temwan so lepok = He \nhad faith in his mission as witness (of) his \nera'),
#  (24, ' Antan ki ekonomis tradisyonel = As a \ntraditional economist'),
#  (24, '  Anterm stratezik = \nIn strategical terms'),
#  (24, ' L i \nbizen gard antet = It must be borne in \nmind'),
#  (24, ' Li \nantor si li ti pe gayn lerim = He’s to blame \nif it got a cold'),
#  (24, '  To antor net = You’re to \nblame only'),
#  (25, ' Li antrenn defet = It results in \ndefeat'),
#  (25, ' Li antrenn pert = It results in losses'),
#  (25,
#   ' Guvernman la deza fini \nantrepran enn stratezi = The government \nhas already introd uced a strategy'),
#  (25,
#   " Eski guvernman vinn ed \nbann antreprener ki'nn fer fayit = Will the \ngovernment come to the aid of \nentrepreneurs that went bankrupt"),
#  (25, ' Antu \nka = At any rate'),
#  (25,
#   '  Li finn tiy \nenn gran kantite dimunn lor lil antye = It \nkilled a lot (of) people on the whole island'),
#  (26, ' Mo antyerman dakor ar twa = I \nfully agree with you'),
#  (26,
#   ' \nAnu fer tu zefor pu nu avway Lareynyon \nenn lasistans medikal = Let’s make all \nefforts to dispatch medical assistence to \nReunion'),
#  (26,
#   '  Diskur \npibliye pu premye fwa dan enn liv separe \ndan versyon orizinal ankreol anut = \nDiscourse published the first time in a \nseparate book in the original version in \nCreole in August'),
#  (26,
#   '  Li ti dir \nbyen poli anver gardyen lanpader la = He \nsaid very politely to the guardian (of) \nstreet lamps'),
#  (26,
#   '  Anverite li ti atire sirtu par planet la \n= In truth he was mainly attracted by the'),
#  (27,
#   ' Anverite bann imen pa  pran buku \nplas lor planet la = In truth the many \nhumans don’t take up much place on \nthe planet'),
#  (27, '  Anverite zye li aveg = In truth \nthe eyes are blind'),
#  (27,
#   '  Anverite paret ki li finn \ntravers lil la anvites = In truth it seems \nthat he crossed the island speedily'),
#  (27,
#   " Mo ti \nanvi tir lenformasyon lor 'ban lezot planet' \n= I felt like getting information about 'the \nother planets'"),
#  (27, ' Li ti santi for enn lanvi \nplore = He felt a strong urge to cry'),
#  (27,
#   ' Anverite paret ki li finn travers \nlil la anvites = In truth it seems that he \ncrossed the island speedily'),
#  (27, ' Li \nanvole, samem apel avyon = It flies, it is'),
#  (28, ' Anvole kuma enn zozo \n= To fly like a bird'),
#  (28, ' Enn anvole = A flight'),
#  (28,
#   ' Apar lelefan \nvizib ek invizib dan vant serpan = Apart \n(from) the visible and invisible elephant in \nthe snake’s belly'),
#  (28,
#   ' Mo konn enn fler ki \npena okenn lezot plas apar kot mwa = I \nknow a flower that doesn’t exist elsewhere \nbut in my home'),
#  (28,
#   '  \nape verbal aspect  : Anu fer enn ve  : ki sa \nbann laliny ki nu ape krir la, pu vinn anba \nso zye = Let’s make a vow  : that the lines \nwe’ve written should be seen by him'),
#  (28, ' Li \nanvole, samem apel avyon = It flies, it’s \ncalled an airplane'),
#  (28, ' Total apepre de \nmilyar gran dimunn ='),
#  (29, ' \nMo pa koz apepre = I don’t talk \nin approximate terms'),
#  (29,
#   ' Mem mo ti apepre \nven met ar miray la mo pa ti truv nanye = \nEven when I was twenty meters from the \nwall I didn’t see anything'),
#  (29, ' \nTu dimunn ti aplodi li = Everybody \napplauded him'),
#  (29,
#   ' \nDan mem fason mo ti aprann enn lot zafer \n= The same way I learned another thing'),
#  (29, ' Apre enn ti \nperyod silans = After a short silence'),
#  (29, '  Mo pa aprivwaze = I’ m not tamed'),
#  (29, ' \nAprivwaz mwa = Tame me'),
#  (29, ' Pa fasil ar zot = It’s not easy \nwith them'),
#  (30, ' Mil mil ar sivilizasyon = A \nthousand miles from civilization'),
#  (30, ' Diferan \nar lezot = Different from the others'),
#  (30,
#   '  Kan mo ti \nenn ti garson, lalimyer arbdenoel, lamizik \nlames minwit, surir boner lor figir dimunn \nki ti fer kado noel vinn spesyal = When I \nwas a small boy, the things that made \nChristmas gifts become special were the \nlights (of) the Christmas tree, the music \n(of) the midnight mass, the smile (of) \nhappiness on the face (of) people'),
#  (30,
#   ' Zot \ndir u aret radote kuma zanfan = They say \nstop chattering like a child'),
#  (30,
#   ' Kan sa ti arive, mo ti refiz koz lor \nserpan, lafore vyerz, usa zetol = When this \nhappens, I refuse to talk about snakes, \njungles or stars'),
#  (30, ' Ki ti ariv bann pye = We'),
#  (31, '  Ki arive \n= What happened'),
#  (31, ' Pa kapav \nfer aryer = Impossible to turn back'),
#  (31,
#   '  Vyolans kont fam dan lakaz ek \ndan lari pe ogmante, ena asasina dan fami \nek vwazinaz = Violence against women at \nhonme and on the streets  is on the increase, \nthere are killings in the family and the \nneighborhood'),
#  (31,
#   ' Sa li ase pu \nki li ere kan li admir zetol = It’s enough \nfor him to be happy when he admires the \nstars'),
#  (31, ' Mo pa fer ase lezersis = I don’t \nmake enough exercise '),
#  (31,
#   ' Li ti sir \nli ti pu asiste nesans enn mirak = He was \nsure he could assist the birth of a miracle'),
#  (32,
#   ' Li rod \nenn plas pu asize me imans manto rwayal \nti finn bar tu plas = He looked for a place \nto sit but the immense royal coat occupied \nall space'),
#  (32, ' Eski mo kapav asize = May I sit \ndown'),
#  (32,
#   ' Li ti pe \npran lapenn swazi kuler asorti = It was \ntaking care to choose the various colors'),
#  (32,
#   '  Atuzame so non pu res asosye \nek sa epidemi ki Moris inn fek sibi = Let \nhis name forever be associated with this \nepidemic that hit Mauritius'),
#  (32,
#   ' \nAlerman nu asper kan mem ki fatalite \nnapa pu tus sak fami opwen ki zot nom pu \ndiminye net = Still, we hope the deaths do \nnot affect each family to the point that \ntheir numbers would diminish '),
#  (33, ' ki lespwar li vre = We hope that the hope \nis true '),
#  (33, '  Be mo aste \nnuvo zetol = Why, I buy new stars'),
#  (33,
#   ' Aster \nsey mazin sok ki mo ti ganye = Now try to \nimagine the shock that I got'),
#  (33,
#   ' Mazeste, mo \nkwar mo bizen ale aster = Majesty, I think \nI have to go now'),
#  (33, '  Se aster la = This is now'),
#  (33,
#   ' Mo ena lakaz, aswar li \nvid, lazurne li plen = I have a house, in the \nevening it’s empty, at daytime it’s full'),
#  (33,
#   ' \nAswar mo truv enn bann lagrenn dan mo \nlaplenn = In the evening I see a lot (of) \ngrains in my plain'),
#  (33,
#   '  Pandan lazurne mo \nrepoze, aswar mo dormi = During the day \nI rest, during the night I sleep'),
#  (34, ' Zot \nfin atak mwa dan sime = I was attacked in \nthe street'),
#  (34, ' Parfwa \nsan atann = Sometimes unexpectedly'),
#  (34, ' \nBizen atan soley kuse = We have to wait \nfor the sunset'),
#  (34,
#   " Li ki ti pe atann parol \nrepros pa'le kwar so zorey = He who had \nalways expected reproach couldn’ t believe \nhis ears"),
#  (34,
#   " Mo pu donn twa enn lakord pu \natas li dan lazurne ek enn pike 'si = I can \ngive you a cord for tying him up for the \nday and also a stake"),
#  (34,
#   ' Si to pa atas li, li pu \nal trene ek li kapa v perdi = If you don’t tie \nhim up, he might wander off and get \nlost'),
#  (34, ' Pa pu kapav atas li = It’ll be \nimpossible to tie it up'),
#  (35,
#   " L i'nn desid \npu les dimunn debark ater = He has \ndecided to let the people leave ship"),
#  (35, ' L i ateri \nlor planet la = He landed on the planet'),
#  (35,
#   '  Anverite \nli ti atire sirtu par planet la = In truth he \nwas mainly attracted by the planet'),
#  (35,
#   '  Li ti \nmars e atraver laplen ros ek lanez, ek anfen \nli ti dekuver enn larut = He walked across \nplains (of) rock and snow, and finally he \ndiscovered a road'),
#  (35,
#   '  Li ti ule atupri sirviv sa kriz la e \nsurti anrisi apre = He wanted  to survive \nthis crisis at any price and enrich himself \nafterwards'),
#  (36, ' vites = A third illuminated express passed \nwith all speed'),
#  (36,
#   '  Atuzame so  non pu res asosye ek \nsa epidemi ki Moris inn fek sibi = Let his \nname forever be associated with this \nepidemic that hit Mauritius'),
#  (36,
#   ' \nZimaz la ti montre enn serpan ki ti pe aval \nenn zanimo feros = That picture show ed a \nsnake devouring a beast'),
#  (36,
#   '  Si u aval enn \npilil par semenn, nepli neseser bwar dilo \nditu = If you swallow one pill per week, \nyou don’t have to have water at all'),
#  (36,
#   ' Enn pye li \npa ne gran; li ti avan = A tree isn’t large; \nit’s small at first'),
#  (36,
#   ' Me si se move zerb ki pe \npuse, vit -vit bizen ras li avan li fer fraka = \nBut if these are bad herbs that keep \npushing, they must be torn quickly before \nthey make trouble'),
#  (37,
#   ' Lerwa ti avans so man to enpe pu \nfer enn ti plas = The king moved his coat a \nbit to make some place'),
#  (37,
#   '  Plis ler avanse, \nplis mo pu kontan = The more advanced \nthe hour, the more I get happy'),
#  (37, ' Anverite \nzye li aveg = In truth the eyes are blind'),
#  (37,
#   ' Bann gran \ndimunn lerla konsey mwa pa perdi letan ar \ndesen serpan avek lelefan = The adults \nthen advised me not to waste time with \ndrawings (of) snakes with elephants'),
#  (37,
#   '  Malerezman, \nsa pa finn arive anda t 25 avril = \nUnfortunately, it arrived on April 25'),
#  (37, ' Pa kapav avway li manze = Can’t \nsend him food'),
#  (37,
#   '  Mo avway zot tren agos ek \nadrwat = I dispatch their trains to the left \nand to the right'),
#  (38,
#   ' Dan \navyon mo finn al buku landrwa dan \nlemonn = In the airplane I went to many \nplaces in the world'),
#  (38,
#   ' Li \naziste  so bann petal ar presizyon = It \nadjusted its petals with precision'),
#  (38,
#   ' \nEnpe pli tar li ti azut sa parol la = A bit \nlater he added this sentence'),
#  (38,
#   ' Li pas so lavi \nazut enn sif ar enn lot = He spends his life \n(by) adding  a number to another'),
#  (38, '  Li ti azut \nde trwa parol = He added a few words'),
#  (39,
#   '  Mo ramas bann \nvwayazer par bach = I arrange \nthe travelers per batch'),
#  (39, ' Li pa enn \nbachara = He isn’t a good -for-nothing'),
#  (39,
#   '  Mo \nenn bachara, pa enn prens  = I’m a good -\nfor-nothing, not a prince '),
#  (39,
#   ' Enn  sans li \ntruv enn bag kuler lalinn buze dan disab = \nBy chance he noted a moon -colored ring \nmoving in the sand'),
#  (39,
#   '  Kuma enn \nzozo ki ti finn gayn kut bal = Like a bird \nhit by a bullet'),
#  (40,
#   '  Li ti pe asiz lao, lipye balans -\nbalanse = He was sitting above, swinging \nhis le gs'),
#  (40, ' Banane \nsenkant = The fifties'),
#  (40, ' Mo ena \nenn bann zanfan = I have a lot (of) \nchildren'),
#  (40, ' Bann zistwar vre = True stories'),
#  (40,
#   ' \nMo finn pas buku letan ar bann gran \ndimunn = I’ve spent much time with \nadults'),
#  (40,
#   ' Enn lelefan bar tro buku plas = An \nelephant occupies too much space'),
#  (40,
#   ' Fler ki \npa ti bar plas ek ki pa ti deranz personn = \nA flower that that doesn’t occupy space or \ndisturb anybody'),
#  (40,
#   ' Li rod enn plas pu asize \nme imans manto rwayal ti finn bar tu plas \n= He looked for a place to sit but the \nimmense royal coat occupied all space'),
#  (41,
#   ' Me baobab pa les u gayn bar = But the \nbaobab doesn’t let you have space'),
#  (41,
#   ' \nEnn ko k li lerwa dan baskur = A cock is \nthe king in the courtyard'),
#  (41, '  Mo ti santi \nso ti leker bat = I felt his heart beating'),
#  (41, ' Bato \nlavaper  = Steam -boat'),
#  (41, ' Baton \nzalimet = Match -stick'),
#  (41,
#   ' Later agrikol lor \nbay pu travayer lisansye = Agricultural \nland to be leased to laid off workers'),
#  (41, ' Li ena enn bay repitasyon = \nShe has a good reputation'),
#  (41, ' Li \nbay enn ku = Suddenly it yawned'),
#  (42,
#   ' ti kumans baye = He had to stay on foot \nand as he was very tired, he started to \nyawn'),
#  (42, ' \nLes mo analiz bayman = Let me analyze \nyawning'),
#  (42,
#   ' E nn reny \nbaze lor puvwar leta ki pe deklar li lao tu \nklas sosyal = A reign based on state power \nthat declares itself above all social classes'),
#  (42, ' Enn som bel \n= A nice sum'),
#  (42, ' Ki \nbenefis to dibyen = Your possessions'),
#  (42, ' Ki benefis ena \nladan = What’s the benefit in it'),
#  (42, ' Li \nti bes so latet  = He lowered his head'),
#  (43, ' Bann gro bebet \n= The large beasts'),
#  (43, ' Zot \ndan bez = They’ve been hit'),
#  (43,
#   '  Dan bi nu vinn ed \nbann kamad ki dan sufrans = To the end \nthat we aid our suffering brethren'),
#  (43,
#   '  Enn \nti liv bileng angle ek kreol = A bilingual \nbooklet in English and Creole'),
#  (43, ' Li blize res \ndan so biro = He must stay in his office'),
#  (43, ' Kan lot bis ale = \nWhen does another bus go'),
#  (43,
#   ' Pandan so \nvwayaz li ti panse dan so leker: bann gran \ndimunn zot byen bizar = During his trip he \nthought to himself: The adults are very \nodd'),
#  (43, ' Donn nu \nzordi dipen ki nu bizen = Give us today'),
#  (44, ' Plim bizen lank = A \npen needs ink'),
#  (44,
#   ' Bizen aksepte zeografi ti \nfinn bye n ed mwa = The need to accept \ngeography helped me a lot'),
#  (44,
#   ' Sa misye la ti \ntelman bizi ki li pa ti mem lev so latet ler \nli ti arive = This gentleman was so busy \nthat he didn’t even raise his head when he \narrived'),
#  (44,
#   ' Kan gran \nmama nwar sante tu so ti blan danse = \nWhen the black grandma sings all her \nwhite grandchildren dance'),
#  (44, ' Li ti fini vinn \nblem ar lakoler = He became  pale with \nanger'),
#  (44, ' Pa bliye \nki mo la = Don’t forget that I’m here'),
#  (45,
#   ' sivilizasyon = Don’t forget that I was \nmore than a thousand miles from \ncivilization'),
#  (45,
#   ' Mo pe sey dekrir li pu ki mo \npa bliye li = I keep trying to describe him \nso that I don’t forget him'),
#  (45,
#   ' \nMo ti blize swazi enn lot metye = I was \nobliged to choose another job'),
#  (45,
#   ' Enn \ndiktater tirk ti defann dimunn so pey met \nlenz tirk ek bliz zot met lenz Lerop = A \nTurkish dictator prohibited the people (of) \nhis country to put on Turkish clothing and \nobliged them to put on European clothing'),
#  (45,
#   ' Enn bomaten, zis kuma soley pe \nleve, li ti devwal so  sekre = One morning, \njust as the sun was rising, it revealed its \nsecret'),
#  (45, ' Si to fer bon = \nIf you’re good'),
#  (46, ' \nMo ruz dan mo boner = I’m red in my \nhappiness'),
#  (46, ' S ey truv to boner lot kote = \nTry to find your happiness elsewhere'),
#  (46,
#   ' So \nti figir la ti eklere ar boner = His small \nface lit up with joy'),
#  (46, ' \nKan boner gramaten = At dawn'),
#  (46,
#   ' Mo \nde ti bonom m ars ansam, sak enn so tur \ndivan = My two little chaps walk together, \neach one in his turn goes first'),
#  (46,
#   ' Alor dir \nmwa kimanyer mo ti bonom pa ti paret \nperdi sime, fatige, swaf usa per = Then tell \nme how come my little chap doesn’t seem \nto be lost, tired, thir sty or scared'),
#  (46,
#   ' \nBonzur misye, ala u sapo drol la = Good \nmorning sir, your hat is quite odd'),
#  (47,
#   ' Li ti pe \nokip detay so bot e = It was busy to take \ncare of the details (of) its beauty '),
#  (47,
#   ' Seki fer \nbote dezer se ki kikpar li pe kasiet enn \nlasurs = What makes the beauty (of) the \ndesert is that somewhere a source may be \nhidden '),
#  (47,
#   ' Problem ladrog pe vinn \nplis repandi, ek rezilta ki vol ek brakaz pe \ntrakas dimunn anpermanans = The drog \nproblem is spreading, and the result is that \ntheft and burglary harass the people all the \ntime'),
#  (47,
#   '  Li ti \nturn otur so sevi kuma enn brasle anor = It \ntwisted  around his ankle like a golden \nbracelet'),
#  (47,
#   ' Enn ti \nbren lerb ver timid -timid ki lev latet ver \nsoley = A small green shy shoot (of) grass'),
#  (48,
#   ' \nEnn bren so ley ase pu li = A \nray (of) sunshine is enough for him'),
#  (48, '  Mo dibut brit \n= I jumped to my feet'),
#  (48, '  So mord tiy brit = \nIts bite kills immediately'),
#  (48,
#   ' Ar \nlapo lis, poli ek zoli ki briye = With \nsmooth, polished and nice skin that shines'),
#  (48,
#   ' \nDan avyon mo finn al buku landrwa dan \nlemonn = In the airplane I went to many \nplaces in the world'),
#  (48, ' To kwar li manz buku \nlerb = Do you think he eats much grass'),
#  (49, ' Enn buk sa \n= This is a buck'),
#  (49,
#   '  Ar \nlalimyer lalinn mo ti pe get so fron pal, so \nzye ferme, so bann buk sive = In the \nmoonlight I was watching his pale \nforehead, his closed eyes, his locks (of) \nhair'),
#  (49,
#   ' Aswar u \nbizen met mwa anba enn bul transparan = \nThis evening you have to put me inside a \ntransparent globe'),
#  (49, ' Li kontan galupe ek \nzwe bul = He likes to run and play ball'),
#  (49,
#   ' Mo ti pe \nkonsantre lor enn bulon tro sere ki mo ti \npe sey devise = I concentrated on a too \ntight bolt that I was trying to undo'),
#  (49,
#   '  Mo krir lor enn but papye \nkomye zetol mo ena = I write on a piece \nof paper how many stars I have '),
#  (50, ' pandan enn bon but letan = He stared at it \nfor a long while '),
#  (50,
#   ' Enn ta \nbutey vid ek enn ta butey plen = A lot of \nempty bottles and a lot of full bottles'),
#  (50,
#   '  Butikye la konn zis so profi, pa \nlamitye = The  shop -owner only knows his \nprofit, not friendship '),
#  (50,
#   ' Li ti vey \ndevlopman buton la zuranzur = He \nobserved the development (of) that bud \ndaily'),
#  (50, ' \nLerla zot nepli kapav buze = Afterwards \nthey cannot move anymore'),
#  (50,
#   ' Buz -buz so  \nlatet dusman li fikse mo avyon = Moving \nhis head slowly, he stared at my plane'),
#  (50,
#   ' To \nnek ena pu buz to sez de trwa pa = You \nonly have to move your chair a few steps'),
#  (51, ' Gran bwa = \nForest'),
#  (51, ' Bwa deben dan dilo = Ebo ny wood \nin the water'),
#  (51, ' Bwa deben lao ranpar = \nEbony wood on the rampart'),
#  (51,
#   '  Nu finn truv \ndimunn kanp dan danbwa, zis pu atann \nlafen sa lepidemi la = We find people \ncamping in the woods, just waiting for the \nend of this epidemic'),
#  (51, '  Mo pe \nbwar enn ti = I drink a bit'),
#  (51, ' Kifer to bwar \nlarak kumsa = Why do you drink like \nthat'),
#  (51,
#   ' Si u aval enn pilil par semenn, nepli \nneseser bwar dilo ditu = If you swallow \none pill per week, you don’t have to have \nwater at all'),
#  (51, ' Li ti get \nli byen = He looked at it thoroughly'),
#  (51, ' \nSirman byen zoli = It’s sure it’s very nice'),
#  (52,
#   ' fann lor Lerop = It almost reached L ondon, \nand soon could spread all over Europe'),
#  (53, '  Mo al chake \nanliberte = I go and walk about as I please'),
#  (53, '  Al cheke lor \nsayt = To go and check on site'),
#  (53, '  Li ti chonb  tayit \n= He remained silent'),
#  (53, ' Fler la chonb tayit = \nThe flower remained silent'),
#  (53,
#   '  Kan li ti finn \nchonb kiksoz, li pa ti large = When he \nseized something'),
#  (53,
#   '  Duler \nrematis chonb mwa napa les sape = \nRheumatic pain overcame  me (and) it \nwon’t go  away'),
#  (53, '  Lafatig chonb li = \nExhaustion overcame him'),
#  (53,
#   ' Pa kone kifer \nenn sagren fon ti chon mwa par lagorz = \nDon’t know why, deep sorrow fell on me'),
#  (54, ' To ti \ntruv drol dabor = You looked strange at \nfirst'),
#  (54,
#   ' Li krir ar kryon dabor ek lerla li krir \nar plim ek lank = He writes with pencil at \nfirst and then he writes with pen and ink'),
#  (54, ' \nMo pa dakor ki = I don’t like if '),
#  (54, ' Mo \nantyerman dakor ar twa = I fully agree \nwith you '),
#  (54, ' Zot ti tom dakor = They made a \ndecision '),
#  (54, ' Dan liv la = In \nthat book'),
#  (54,
#   ' Dan mo lavi mo finn zwann \nenn ta dimunn serye = In my life I’ve met \na lot (of) serious people'),
#  (54, ' Sap dan karay \ntom dan life = Out of the frying pan into \nthe fire'),
#  (55, ' Sap dan karay tom dan life \n= Out of the frying pan into the fire'),
#  (55, ' Surti \ndan lesyel = To come out of the sky'),
#  (55,
#   ' Ler lizur ti kumans leve mo ti \ndekuver enn danpi = When the sun started \nto rise I discovered a well'),
#  (55,
#   ' Kan \ngran mama nwar sante tu so ti blan danse \n= When the black grandma sings all her \nwhite grandchildren dance'),
#  (55,
#   ' Bann saser tule \nzedi zot danse ar bann manzel dan vilaz \n= The hunters every Thursday dance with \nthe girls in the village '),
#  (55, ' Li ti danse rant dan \nsalon = He entered to the hall dancing'),
#  (55,
#   '  Li pa \nkonpran danze divan nu = He doesn’t \nunderstand the dangers facing us'),
#  (55, ' \nEnn serpan li danzere = Snakes are \ndangerous'),
#  (56,
#   ' Ek \ndapre twa li pa serye sey konpran kifer \nbann fler kontinye fabrik pikan mem si sa \npa itil = And according to you, it’s not \nserious to try to understand why flowers \ncontinue to produce thorns even if that’s \nnot useful'),
#  (56, '  Dapre ri mer = Rumor has it'),
#  (56, '  Pena plas pu de = \nThere’s no space for two'),
#  (56,
#   '  Mo de ti bonom \nmars ansam, sak enn so tur divan = My \ntwo little chaps walk together, each one in \nhis turn goes first'),
#  (56,
#   ' Mo de p romye desen ti \nfel dapre bann gran dimunn = My first two \ndrawings failed with the adults'),
#  (56, ' Mo frot \nmo zye de trwa fwa = I rub my eyes a few \ntimes'),
#  (56, ' De trwa mo sap parsi -parla = A few \nwords uttered here or there'),
#  (56,
#   ' To nek ena pu \nbuz to sez de trwa pa = You only  have to \nmove your chair a few steps'),
#  (57, ' Deba piblik \n= Public debate'),
#  (57,
#   '  Ler li ti debarke lor \nTer, li ti gayn sok = When he landed on \nEarth, he became shocked '),
#  (57,
#   " Li'nn desid pu \nles dimunn debark ater = He has decided \nto let the people leave ship "),
#  (57, ' Zot \ndedomaz bann ti -planter = They \nindemnify the tea planters'),
#  (57,
#   ' Zot sey defann zot lavi kuma zot \nkapav = They try to defend their life as \nthey can'),
#  (57,
#   '  Apar kat pikan li pa ena nanye \npu defann li = Apart from four thorns he \nhas nothing to defend itself'),
#  (57,
#   ' Enn  diktater \ntirk ti defann dimunn so pey met lenz tirk \nek bliz zot met lenz Lerop = A Turkish \ndictator prohibited the people (of) his'),
#  (58, '  Sa \nkriz la pe deferle = This crisis is unfurling '),
#  (58, ' \nAlor les mo sanz dedikas la = Then let me \nchange that dedication'),
#  (58,
#   ' \nPardonn mwa si mo pe dediye sa liv la pu \nenn gran dimunn = Excuse me if I  \ndedicate this book to an adult'),
#  (58,
#   " Bann \nlafors revolisyoner ti 'nn epwize, ti 'nn sibi \ndefet = The revolutionary forces have got \nexhausted, have been defeated"),
#  (58,
#   ' Si kikenn anpr omye gayn enn lide, \nli deklar li, li patant li = If somebody gets \nan idea first, he declares it, he patents it'),
#  (59,
#   ' Li \nti pe syeze lor so tron senp me rwayal dan \nso manto ruz ek dekore ar furir blan = He \nwas seated on h is simple but royal throne \nin his red coat decorated with white fur'),
#  (59,
#   ' Mo \npe sey dekrir li pu ki mo pa bliye li = I \nkeep trying to describe him so that I don’t \nforget him'),
#  (59, ' Li ti pe kumans dekuraze = \nHe started to lose courage'),
#  (59,
#   ' \nKan enn astronon dekuver en, li donn li \nenn nimero = When an astronomer \ndiscovers one, he gives it a number'),
#  (59,
#   ' \nAstronon la ti refer prezantasyon so \ndekuvert an 1920 = This astronomer \nrepeated the presentation (of) his 1920 \ndiscovery'),
#  (60,
#   ' Ena dimunn pe tante pu demar enn ti \nlanterpriz = There are people who try to \nstart a sma ll business'),
#  (60,
#   '  Li \nenn liv estra bote ki zame demode = It’s a \nbook of extraordinary beauty that will \nnever become obsolete'),
#  (60,
#   ' Mo ti prese pu demont mo \nmoter = I hurried to disassemble my \nengine'),
#  (60,
#   ' Apre bann Lafrik ek \nLerop; apre bann Lamerik Desid ek \nLamerik Denor = After those (of) Africa \nand Europe; then those (of) South \nAmerica and North Ameri ca'),
#  (61,
#   ' Enn program devlopman \nbann lasurs lenerzi renuvab pu diminye \ndepandans lor emportasyon prodwi \npetrolye = A development program (of) \nrenewable energy sources to  diminish \ndependence on the imports (of) petroleum \nproducts'),
#  (61,
#   '  Seki neseser zordi, se enn \nlekonomi alternativ ki pa depann lor disik, \nkann ek tekstil = What is necessary today \nis an alternative economy not depending \non sugar, cane and textiles'),
#  (61,
#   ' Sak \nzur mo ti pe aprann enn ti zafer lor sa \nplanet la, lor so depar, lor so vwayaz = \nEach day I learned a bit about that planet, \nhis departure, his trip'),
#  (62, ' Zot bizar depas kad = They’re \nextremely odd'),
#  (62,
#   ' Fler ki pa ti bar plas ek ki pa ti \nderanz personn = A flower that that \ndoesn’t occupy space or disturb \nanybody'),
#  (62,
#   '  Zis trwa fwa finn deranz mwa = \nI have been disturbed only three times'),
#  (62, ' Dernye model = Last model'),
#  (62, ' Dernye \nsekur la = The last help'),
#  (62, ' Lane dernye = \nLast year'),
#  (62, ' Dernye gut = Last drop'),
#  (62, ' Dernye \nfwa = Last time'),
#  (62, ' Enn dernye ku = The last \ntime'),
#  (62,
#   '  Zis \nbann zanfan, nene plake lor vit, get lavi pe \nderule = Only the children, their noses'),
#  (63,
#   '  Tu sa bann fe ki \nti finn derule la = All the facts that were \npresent there'),
#  (63,
#   ' Zame mo te kapav truve sa ki \ngayn deryer mo lakaz = I’ve never been \nable to find ou t what’s behind my house '),
#  (63,
#   ' \nLi ti vir deryer anmemtan me li pa ti truv \npersonn = He turned around at the same \ntime but he didn’t see anybody '),
#  (63,
#   '  Lagazet ti pe \nanons ki nek dan sa trwa dernye zur, bann \ndese inn ariv enn sif ki plis ki lidub \nmoyenn bann dese ki ti ena avan la = The \npaper announced that just in the last three \ndays, the deaths reached a number that \nwas more than twice that before'),
#  (64, ' mo promye desen = It gave me the idea to \nmake my first drawing'),
#  (64,
#   ' Apre bann Lafrik ek \nLerop; apre bann Lamerik Desid ek \nLamerik Denor = After those (of) Africa \nand Europe; then those ( of) South \nAmerica and North America'),
#  (64, " To'nn \ndeside pu ale = You’ve decided to leave"),
#  (64, ' Pa sapo ki mo ti \ndesine = It’s not a hat I’ve drawn'),
#  (64, ' Desin \nenn muton pu mwa = Draw me a sheep'),
#  (64,
#   ' Mo lidwa nwar ar lagres ek deswif \n= My fingers were black with grease and \ntallow'),
#  (64, ' Deswit zot pu kriye = Then they cry \nout'),
#  (65, '  Fors dimunn \nrant dan det = Many people accumulate \ndebts'),
#  (65,
#   ' Sa donn zot \nlenpresyon ki sa bann detay la fer zot \nkonn dimunn la = It gives them the \nimpression that such many details make \nthem know that man'),
#  (65, ' Mo \ndeteste kurander = I detest air drafts'),
#  (65,
#   ' Kree \nlanplwa pa detrir lanplwa = \nCreate  employment instead of destroying \nemployment'),
#  (65,
#   ' Presk tu dimunn pe truv zot nivo devi \nmenase = Almost everbody sees his \nstandard of living being threatened'),
#  (66,
#   ' \nMo ti pe konsantre lor enn bulon tr o sere \nki mo ti pe sey devise = I concentrated on \na too tight bolt that I was trying to undo'),
#  (66,
#   '  Kuma li kapav devlope dan sa \nbann rezyon la = How could it spread in \nthese regions'),
#  (66,
#   '  Proteksyonism ki finn \npermet lendistri sikryer ek tekstil devlope \nek sirviv, sa pe disparet = Protectionism \nthat allowed the sugar and textile \nindustries develop and survive has \ndisappeared'),
#  (66,
#   ' Li ti vey devlopman buton \nla zuranzur = He o bserved the \ndevelopment (of) that bud daily'),
#  (66,
#   ' Bann gran miltinasyonal, amizir \nzot globalize, devor ti konpanyi la = The'),
#  (67,
#   ' Enn bomaten, zis kuma soley pe \nleve, li ti devwal so sekre = One morning, \njust as the sun was rising, it revealed its \nsecret'),
#  (67,
#   '  Pa gaspiy letan fer devwar enitil = \nDon’t wast e the time by doing useless \ntasks'),
#  (67, ' Enn \nmaser devwe ek saritab = A devoted and \ncharitable nun'),
#  (67,
#   " To'nn deza \ntann dir ki enn losean finn sek = You’ve \nalready heard saying that an ocean dried \nup"),
#  (67,
#   " To'nn deza tann dir ki enn montany \nfinn sanz plas = You’ve already heard \nsaying that a  mountain changed its \nplace "),
#  (68,
#   ' lafrod la, li ti deza tro tar = When the \nauthorities found the fraud, it was already \ntoo late'),
#  (68, ' Ena \nven dezan = Twenty two years ago'),
#  (68,
#   ' Ziska \nki enn zur, ena sizan disela, mo ti gayn \nenn pann dan dezer = Until one day six \nyears ago I got an accident in the desert'),
#  (68,
#   ' \nFors dimunn  rod emigre dan dezespwar = \nA lot of people lose hope and seek \nemigration'),
#  (68, ' Li pa ti toler dezobeysans = \nHe didn’t tolerate disobedience'),
#  (69,
#   ' kumans fer so dezord = A maybug, who \nknows whence, started to make a disorder'),
#  (69, ' Mo \nena enn dezyem rezon = I had a second \nreason'),
#  (69,
#   ' Promye desen korek me deziem \nenn flop = The first drawing is OK but the \nsecond is a failure'),
#  (69, ' Dezyem vag = Second \nwave'),
#  (69, ' Si \nto truv enn diaman = If you find a \ndiamond'),
#  (69,
#   '  To truv sa \nbann karo dible la = Do you see the wheat \nfields there'),
#  (69,
#   ' Ki dibon to \nfer pu to zetol = What good things you \nmake for your star'),
#  (69, ' Mo dibut, li alonze = I’m standing,'),
#  (70, ' Li dibute kuma enn gunga = \nHe stood speechless'),
#  (70, '  Mo dibut brit = I \njumped to my feet'),
#  (70,
#   '  Li dibut drwat san \nbuze enn ti mama = He stood erect \nmotionless for a moment'),
#  (70, ' \nMo dibyen sa = I possess them'),
#  (70, ' Ki benefis \nto dibyen = Your possessions'),
#  (70,
#   '  So \nlide ti net diferan ar seki  gran dimunn ti \npanse  = His ideas were very different \nfrom what the adults thought'),
#  (70, ' Difisil \npu konpran fler = It’s hard to understand \nthe flowers'),
#  (71, ' Enn ver dile = A \nglass (of) milk'),
#  (71, ' Bwa deben dan \ndilo = Ebony wood in the water'),
#  (71, '  Dilo \nbyen bon pu leker = Water is very good \nfor the heart'),
#  (71,
#   ' Mo \ndimann zot si zot pa gayn per = I asked \nthem if they didn’t get frightened'),
#  (71, ' Li \nfasil dir dimen mo pu fer li = It’s easy to \nsay tomorrow'),
#  (71,
#   '  To kone ler mo ti tom lor \nlater, dimen so laniverser = You know \nwhen I fell to earth, tomorrow will be its \nanniversary'),
#  (72, ' surir = His half open lips formed a littl e \nsmile'),
#  (72,
#   ' Stok dilo ti pe diminye tro vit = \nThe water reserves went down too \nfast'),
#  (72,
#   ' Alerman nu asper kan mem ki fatalite \nnapa pu tus sak fami opwen ki zot nom pu \ndiminye net = Still, we hope the deaths do \nnot affect each family to the point that \ntheir numbers would diminish'),
#  (72, ' Bann \nmus dimyel = Bees'),
#  (72,
#   '  Boner sa gramaten la \ndisab ti kuler dimyel = This morning very \nearly the sand had the color (of) honey'),
#  (72, ' Tu dimunn konn sa = \nEverybody knows that'),
#  (72, ' Tu dimunn ti \naplodi li = Everybody applauded him'),
#  (72,
#   ' Mo \nmontre mo desen bann gran dimunn = I \nshow(ed) my drawing (to the) adults'),
#  (72, ' Pu \ned gran dimunn konpran = To help adults'),
#  (73,
#   ' Enn diktater tirk ti defann \ndimunn so pey met lenz tirk ek bliz zot \nmet lenz Lerop = A Turkish dictator \nprohibited the people (of) his country to \nput on Turkish clothing and obliged them \nto put on European clothing'),
#  (73,
#   ' Donn nu \nzordi dipen ki nu bizen = Give us today \nthe bread we need'),
#  (73, '  Mo pa manz dipen   = I \ndon’t eat bread'),
#  (73, ' Dipi laz \nsizan = Since the age (of) six'),
#  (73,
#   ' Dipi plizir \nmilyon bann ane bann fler fabrik pikan = \nThe flowers have produced thorns for \nmillions of years'),
#  (73,
#   ' Mo ti plis ki mil mil distans \ndipi sivilizasyon = I was more than a \nthousand miles from civilization'),
#  (73, '  Kot u \nkonsey mwa ale dipi isi = Where do you'),
#  (74, ' Dipi enn \ndistans = From a distance'),
#  (74,
#   ' Zot dir mwa \nsapo pa fer dimunn per = They tell me a \nhat doesn’t make one scared'),
#  (74,
#   ' Ler mo reysi \nkoze, mo ti dir li = When I managed to \ntalk, I said to him'),
#  (74,
#   ' \nEnn lot tren ekspres ti pas dan lot \ndireksyon =  Another express passe d in the \nother direction '),
#  (74, ' Marmit diri lao \nlife = Rice pot on the fire'),
#  (74,
#   '  Sizyem planet la ti \ndis fwa pli gran = The sixth planet was ten \ntimes bigger'),
#  (75,
#   ' Promye \nleswar la mo ti  dormi lor disab = That first \nevening I slept in the sand'),
#  (75,
#   ' Enn  sans li \ntruv enn bag kuler lalinn buze dan disab = \nBy chance he noted a moon -colored ring \nmoving in the sand '),
#  (75,
#   ' Normalman li zis enn \ntru dan disab = U sually it’s just a hole in \nthe sand'),
#  (75, '  Mo anvi disann = I feel like \ngetting off'),
#  (75,
#   ' Ziska ki enn \nzur ena sizan disela mo ti gayn enn pann \ndan dezer = Until one day six years  ago I \ngot an accident in the desert'),
#  (75,
#   '  Seki neseser \nzordi, se enn lekonomi alternativ ki pa \ndepann lor disik, kann ek tekstil = What is'),
#  (76,
#   '  Diskur pibliye pu premye fwa \ndan enn liv separe dan versyon orizinal \nankreol anut = Discourse published the \nfirst time in a separate book in the original \nversion in Creole in  August'),
#  (76,
#   '  Mo fler andanze pu fonn, \ndisparet = My flower is in danger of \ndisappearing'),
#  (76,
#   ' Proteksyonism ki finn \npermet lendistri sikryer ek tekstil devlope \nek sirviv, sa pe disparet = Protectionism \nthat allowed th e sugar and textile \nindustries develop and survive has \ndisappeared'),
#  (77,
#   ' Pa \nbliye ki mo ti plis ki mil mil distans dipi \nsivilizasyon = Don’t forget that I was \nmore than a  thousand miles from \ncivilization'),
#  (77, ' Dipi  enn distans = From a \ndistance'),
#  (77,
#   ' Enn  ti fler \nnanye ditu ar trwa petal = A little \nnondescript flower with three petals'),
#  (77, ' Zot \npa resam mo roz ditu = They don’t \nresemble my rose at all'),
#  (77,
#   ' Mo \nde ti bonom mars ansam, sakenn so tur \ndivan = My two little chaps walk together, \neach one in his turn goes first'),
#  (77, ' Drwat \ndivan li = Right in front of him'),
#  (77,
#   ' Mo ti la \ndivan li, enn marto dan m o lame = I was \nin front of him, a hammer in my hand'),
#  (77, ' So sive \nkuler lor ti pe fane dan divan = His gold'),
#  (78, ' Mo \nal kot divan amenn mwa = I go where the \nwind takes me'),
#  (78,
#   '  Ena enn dizenn diferan trak ki \nfinn distribiye par 10,000 kopi = There are \napprox'),
#  (78,
#   '  Sak fwa li \nteyn li savedir li ler pu fler ek zetol al \ndodo = Each time he extinguishes it that \nmeans he (makes) a flower or a star go to \nsleep'),
#  (79,
#   ' move maladi la = A doctor who already \nhad experience (with) this evil disease'),
#  (79,
#   ' \nDonn nu zordi dipen ki nu bizen = Give us \ntoday the bread we need'),
#  (79,
#   ' Li ti donn mwa \nlide pu mo fer mo promye desen = It gave \nme the idea to make my first drawing'),
#  (79, ' Zoli donk \nneseser = Nice so its’s necessary'),
#  (79,
#   ' Bann ti zafer \ndore ki fer bann par es reve = Many small \ngolden things that make lazybones dream'),
#  (79, ' Zot \ndormi pandan sis mwa = They sleep for \nsix months'),
#  (79,
# ...
#  (137,
#   ' \nMazeste, mo kapav konfirme pena \npersonn = Majesty, I can confirm there’s \nnobody'),
#  (137,
#   ' \nKan nu sir ki kapav fer li konfyans, lerla \nnu fer enn lanket lor so dekuvert = When \nwe are sure we can trust him, then we \nmake an inquiry on his discovery'),
#  (137, ' Fer \nmwa konfyans plito = Rather trust me '),
#  (138, ' Mank \nkonfor = Lacks comfort'),
#  (138, ' Ti \nkler ki li ti pe gayn kongolo = Clearly he \ngot confused'),
#  (138,
#   '  A tu \ndimunn koni usa enkoni ki lye pasyon \nrevolisyoner ave k pasyans revolisyoner \n= To all known or unknown people  who \ncombine revolutionary passion with \nrevolutionary patience'),
#  (138, ' \nMo pu bizen konpanyi = I might need \ncompany'),
#  (138, '  Non tro konplike = No it’s \ntoo complicated'),
#  (139, ' Pu ed gran dimunn konpran = \nTo help adults understand'),
#  (139,
#   ' Sa zot pa \nkonpran nanye ek n u zanfan nu fatige nek \nesplik zot tu zafer = They don’t \nunderstand anything and we children \nwe’re tired just to explain to them \neverything'),
#  (139,
#   ' Nu bann zanfan nu bizen pe \nsey konpran bann gran dimunn = We \nchildren we have to keep trying to make \nadults understa nd'),
#  (139, ' Li pa ti pe konpran \nnanye = He doesn’t understand anything'),
#  (139,
#   ' Bann gran dimunn lerla konsey \nmwa pa perdi letan ar desen serpan avek \nlelefan = The adults then advised me not \nto waste time with drawings (of) snakes'),
#  (140,
#   '  Kot u konsey mwa ale dipi \nisi = Where do you advise me to go from \nhere'),
#  (140,
#   ' Etimolozi li enn syans ki so bi \nmem li konsis pu sers bann mo zot \nlorizinn = Etymology is a science whose \ngoal is to look for the origin (of) words'),
#  (140,
#   '  Ki sann la finn konstat anpromye \nprezans sa mons la = Who ascertained \nfirst the presence (of) this monster'),
#  (140,
#   '  Sa ti fer mwa pli konsyan so \nfrazilite = This made me more conscious \nof his fragility'),
#  (140,
#   '  Mazine ki avan invansyon \nelektrisite, ti ena, lor tu bann kontinan met \nansam, enn larme = Imagine that before'),
#  (141,
#   ' Ek ar enn ti tristes dan so \nlavwa li kontinye = And with a bit (of) \nsadness in his voice he continued'),
#  (141, ' Sa \nbulon la kontinye fer fos = This bolt keeps \non resisting'),
#  (141,
#   '  Guvernman pe kontiyn \nankuraz lisansiman = The government \ncontinues to encourage layoffs'),
#  (141, ' K onsol mwa = Console me'),
#  (141, '  Mo \nbizen konsol li = I have to console him'),
#  (141, '  Li \nti konsol mwa = He consoled me'),
#  (141, ' \nLi pa ti pran kont trwa ti pye = He ignored \nthree bushes'),
#  (141, ' Mo \nkont lapenndemor = I’m against the death \npenalty'),
#  (142, ' \nMo kontan twa = I like you'),
#  (142, ' Mo ko ntan \nfinn zwann u = Nice to see you'),
#  (142, ' Ki zwe li \nkontan zwe = What games he likes to play'),
#  (142,
#   ' \nPa kont lor mwa pu mo desen mo avyon = \nDon’t count on me that I (could) draw my \nairplane'),
#  (142,
#   ' Li korek sa kes ki to finn donn mwa; \naswar li kapav dormi ladan = Th e box you \ngave me is OK; in the evening he can \nsleep inside'),
#  (142, ' Gete, li ena \nkorn = Look, he has horns'),
#  (143,
#   ' renar, zot kuma korn = Look at the ears \n(of) your fox, they’re like horns'),
#  (143, ' Sankutla \nli ti met kostin = This time he put on a suit'),
#  (143,
#   ' Ti koson \nriye nene so mama = The piglet laughs (at) \nthe nose (of) its mom'),
#  (143, ' \nKot mwa pena buku plas = Where I live \nthere’s not mu ch space'),
#  (143,
#   ' Ti pran mwa buku \nletan pu konpran kot li ti sape = It took me \na long time to understand where he came \nfrom'),
#  (143, ' Kot mo ale li swiv mo = Wherever I \ngo, he follows me'),
#  (143, ' Kot to sape mo ti \nbonom = Where do you come from my \nlittle chap'),
#  (143, ' Kot to reste = Wher e do you \nlive'),
#  (143, " Kot to'le amenn mo muton = Where \ndo you want to take my sheep"),
#  (143, ' Mo bliye \nmo pa kot mwa = I forget I’m not at home'),
#  (143, ' \nKot mo surti = Whence I came'),
#  (144, ' Bon kote \n= The good sides'),
#  (144,
#   ' Sey truv to boner lot \nkote = Try to find your happiness \nelsewhere'),
#  (144,
#   ' \nEnn esplorater manter kapav koz katastrof \n= A lying explorer can cause a catastophe'),
#  (144,
#   ' Ler mo reysi koze, mo ti dir li = \nWhe n I managed to talk, I said to \nhim'),
#  (144, ' Koze, mo ekute = Talk, I listen'),
#  (144,
#   '  Avan eleksyon zeneral ti \nena gran -gran koze lor demokratizasyon \nlekonomi = Prior to the general election \nthere was much talk on the \ndemocratization (of) economy'),
#  (144, ' Mo manz \nmo krann = I have doubts'),
#  (144, ' \nLi pa pete usa kras dife = It doesn’t fart or \nspew fire'),
#  (145, '  Li la ti \nfit so krayon = He sha rpened his pencil '),
#  (145,
#   ' Li \nkrir ar krayon dabor ek lerla li krir ar plim \nek lank = He writes with pencil at first and \nthen he writes with pen and ink'),
#  (145,
#   ' Ar de \ntrwa kut krayon mo ti desen enn mizelyer \n= With a few strokes (of) the pencil he \ndrew a muzzle'),
#  (145, ' Li \nvedir kree bann lyen = It means to create \nlinks'),
#  (145,
#   ' Tu sa la pe kre bann kondisyon \nsanzman = All this created a condition (of) \nchanges '),
#  (145, ' Li kre enn  lenpak sikolozik = It \ncreated a psychological impact'),
#  (145, ' \nLafwa kretyen la = The Christian faith'),
#  (146,
#   ' Kumadir \nkikenn finn komet enn krim kont mwa = \nAs if someone comm itted a crime against \nme'),
#  (146, ' Usa krir \nenn trazedi = Or to write a tragedy'),
#  (146,
#   '  Mo \nkrir lor enn but papye komye zetol mo ena \n= I write on a piece of paper how many \nstars I have'),
#  (146, ' Desuit zot pu \nkriye = Then they cry out'),
#  (146, ' Enn ku li \nkumans kriye -plore = Suddenly he started \nto sob'),
#  (146,
#   '  Repiblik \nMoris finn rant dan enn kriz sistemik = \nThe Republic of Mauritius has entered a \nsystemic crisis'),
#  (146, '  Eski li itil pu krwaz lebra = Should \nwe cross our arms'),
#  (147, ' Mo manz mo \nku = I’m irritated'),
#  (147, ' Enn ku = \nsuddenly'),
#  (147, ' Enn sel ku = At a single blow'),
#  (147,
#   ' \nEnn ku li tro gran, enn ku li tro ti = Now \nit’s too big, now it’s too small'),
#  (147, ' Li bay enn \nku = Suddenly it yawned'),
#  (147,
#   ' Li vini pu roz \nso fler enn dernye ku = He watered his \nflower the last time'),
#  (147, '  Pu sey enn ku = Just \nat random'),
#  (147, '  Larm \nparfw a kule = Tears sometimes flow'),
#  (147,
#   ' Li ti \nkul dan disab kuma enn zedo =  It flowed \nin the sand like a water -jet'),
#  (147,
#   ' Mo nepli \nbyen rapel kuler so lenz = I can’t really \nrecall the color (of) his clothing'),
#  (147,
#   ' So sive \nkuler lor ti pe fane  dan divan = His gold \ncolored hair was fanned in the wind'),
#  (148,
#   ' dan disab = By chance he noted a moon -\ncolored ring moving in the sand'),
#  (148,
#   ' Me li ti \nrezet li kuma lezot = But he rejected it like \nthe others'),
#  (148,
#   ' \nKumadir kiksoz pe manz so kran = As if \nsomething caused him doubts'),
#  (148,
#   ' Me si enn \nmuton manz fler la, li kumadir enn kut sek \ntu zetol teyn = But if a sheep eats t hat \nflower, it’s as if suddenly all the stars \nbecame extinguished'),
#  (148,
#   ' Pli tar li tir mo muton dan so pos \nek kumans admir so trezor = Later he \npulled my sheep from his pocket and \nstarted to admire his treasure'),
#  (148, '  Enn ku li \nkumans kriye -plore = Suddenly he started \nto sob'),
#  (149, ' konn byen sa fler la = Slowly I started to \nknow this flower well'),
#  (149, ' Dan kumansman 19em syek = At the \nstart (of) the 19th century'),
#  (149, ' Zot kumsa = They’re like that'),
#  (149, ' Enpe \nkumsa = Something like that'),
#  (149,
#   ' Tu manyer \nar enn zafer kumsa to pa kapav surti lwan \n= At any rate with such a thing you can’t \ncome from afar'),
#  (149,
#   ' Kumsamem mo ti aprann lor \ntrwazyem zur = Even so I learned on the \nthird day'),
#  (149,
#   ' Li fors \ntuse pli for pu fer li santi kupab = It forced \ncoughing harder to make him feel guilty'),
#  (149,
#   ' Kup \nmo vant u a gayn mo trezor = Cut my \nbelly (and) you get my treasure'),
#  (150, ' Pu fini kur ar \nli = To finish as soon as possible with \nhim'),
#  (150,
#   ' So vizit ti mari kur me ti fer li vinn \ntris = His visit was very short but it made \nhim sad'),
#  (150, ' Mo deteste kurander = I detest air \ndrafts'),
#  (150,
#   ' Li ti \npran kuraz pu dimann lerwa enn faver = \nHe takes the courage to ask the king a \nfavor'),
#  (150,
#   '  Li ti pe kumans regrete m e li ti \nrepran kuraz = He started to regret but he \nregained courage'),
#  (150, ' Soley kuse \nzot surti = The sun sets they come out'),
#  (150, ' Mo \nkontan get soley kuse = I like to watch the \nsunset'),
#  (150, ' Enn \nkut sek = Suddenly'),
#  (150, ' Enn sel kut gete = (At)'),
#  (151,
#   ' Ar de trwa kut krayon mo \nti desen enn mizelyer = With a few strokes \n(of) the pencil he drew a muzzle '),
#  (151,
#   ' \nLepidemi la inn fane enn sel kut lor lil = \nThe epidemic spread very fast  on the \nisland '),
#  (151, '  Senk san \nmilyon kwa  = Five hundred million (of) \nwhat'),
#  (151,
#   '  Mo pu yan \ntwa dan kwan zye = I watch you from the \ncorner (of) my eyes'),
#  (151, ' To \nkwar li manz buku lerb = Do you think he \neats much grass'),
#  (152, ' ar zot = I still think it’s not easy with them'),
#  (152,
#   ' \nParfwa kan mo ti kwar ki mo ti finn \nzwann enn gran dimunn enpe korek, mo ti \nmontre li mo promye desen = Sometimes \nwhen I thought I met an adult who’s a bit \nclever, I showed him my first drawing'),
#  (152, ' \nMo pa kwar nanye = I don’t think \nanything'),
#  (153, ' Dan liv la = In that \nbook'),
#  (153, ' Get mo \nplanet laba = Look at my planet over there'),
#  (153, ' Mo met \nli dan labank = I put it in the bank'),
#  (153,
#   ' Labank \nSantral pu anpese depresyasyon rupi = \nThe Central Bank can prevent the \ndepreciation (of) the rupee'),
#  (153, ' Mo \nblize sanz mo labitid = I’m obliged to \nchange my habit'),
#  (154, ' tirk = But nobody believed him due to his \nTurkish apparel'),
#  (154, ' Lab rim ti \nfini leve = Night has fallen'),
#  (154,
#   '  Labrim ti leve \nek bann zetol ti pe kumans alime dan \nlesyel = Night fell and many stars started \nto light up in the sky'),
#  (154,
#   '  Mo ti \nrekumans santi enn labriz glase teyn mo \nkonfyans = I started  again to feel an icy \nbreeze making my confidence disappear'),
#  (154,
#   '  Se \nvizyon enn roz ki briye dan so nam kuma \ndife labuzi  = This vision (of) a rose that \nshines in his soul like the fire (of) a candle'),
#  (155,
#   ' dormi ladan = The box you gave me is \nOK; in the evening he can sleep inside'),
#  (155, '  Ki \nbenefis ena ladan = What’s the benefit in \nit'),
#  (155,
#   '  Problem \nladrog pe vinn plis repandi, ek rezilta ki \nvol ek brakaz pe trakas dimunn \nanpermanans = The drog problem  is \nspreading, and the result is that theft and \nburglary harass the people all the time'),
#  (155, ' \nLafatig chonb li = Exhaustion overcame \nhim'),
#  (155, ' \nTi ena buku lafeksyon = There was much \naffection'),
#  (156,
#   ' lafen sa lepidemi la = We find people \ncamping in the woods, just waiting for the \nend of this epidemic'),
#  (156,
#   '  Li pa konn \nni laswaf ni lafem = He doesn’t \nknow  thirst or hunger '),
#  (156,
#   ' Enn \nvolkan ki byen rebore, so laflam li du ek \nregilye = A well rebored volcano has a \nflame that’s suave and regular'),
#  (156,
#   ' Mo finn \ntruv enn zoli lakaz anbrik roz ar fler lor \nbor lafnet ek pizon lor so twa = I saw a \nnice pink brick house wit h flowers in the \nwindows and pigeons on its roof'),
#  (156,
#   '  Parfwa \nto pu uver to lafnet = Sometimes you’ll \nopen your window'),
#  (157,
#   ' Kan sa ti \narive, mo ti refiz koz lor serpan, lafore \nvyerz, usa zetol = When this happens, I \nrefuse to talk about snakes, jungles or \nstars'),
#  (157,
#   " Bann l afors \nrevolisyoner ti 'nn epwize, ti 'nn sibi defet = \nThe revolutionary forces have got \nexhausted, have been defeated"),
#  (157,
#   ' Apre \nbann Lafrik ek Lerop; apre bann Lamerik \nDesid ek Lamerik Denor = After those (of) \nAfrica and Europe; then those (of) South \nAmerica and North America'),
#  (157,
#   '  Letan \nbann lotorite finn konpran lafrod la, li ti \ndeza tro tar = When the authorities found \nthe fra ud, it was already too late'),
#  (157, ' Lafwa kretyen \nla = The Christian faith'),
#  (158,
#   '  Mo ti pe \ngayn enn ti lafyev akoz mo ti swaf = \nThirst caused me a slight fever'),
#  (158,
#   ' Lager \nant muton ek fler pa serye = The war \nbetween sheep and flowers is not serious'),
#  (158, ' So lagorz \nti sere = His throat contracted'),
#  (158,
#   ' Aswar \nmo truv enn bann lagrenn dan mo laplenn \n= In the evening I see a lot (of) grains in \nmy plain'),
#  (158,
#   ' Mo lidwa \nnwar ar lagres ek deswif = My fingers \nwere black with grease and tallow'),
#  (159, '  Dimunn inn al fwi dan lakanpany \n= People fled to the country'),
#  (159,
#   ' Mo ena \nlakaz, as war li vid, lazurne li plen = I have \na house, in the evening it’s empty, at \ndaytime it’s full'),
#  (159,
#   ' Zame mo te kapav truve \nsa ki gayn deryer mo lakaz = I’ve never \nbeen able to find out what’s behind my \nhouse'),
#  (159,
#   ' Planet kot li ti surti pa ti pli gran ki \nenn lakaz =  The planet from where he \ncame wasn’t bigger than a house'),
#  (159, '  Mo finn abandon li \ntusel lakaz = I left him alone at home'),
#  (159, ' Zako napa get \nso lake = The monkey does not look at its \ntail'),
#  (159,
#   ' Sankutla grasa \nmuton ki lakle kase = This time the key of \nthe matter was the sheep'),
#  (160, '  Zot sone \nkuma laklos = They sound like bells'),
#  (160,
#   ' Mo \ndonn twa enn ti laklos ki konn riye = I \ngive you a chime that can laugh'),
#  (160, ' Lerla mo \ntann ti laklos plore = The I hear the chime \ncrying'),
#  (160, ' Li ti fini \nvinn blem ar lakoler = He became pale \nwith anger'),
#  (160,
#   " Mo pu \ndonn twa enn lakord pu atas li dan lazurne \nek enn pike 'si = I can give you a cord for \ntying him up for the day and also a \nstake"),
#  (160,
#   '  Tu dan lord: puli, seo, lakord = \nEverything’s in order: the pulley, the \nbucket, the rope'),
#  (160,
#   "  Letan bato  \nfinn ariv pre lakot Lareynyon, li'nn gayn \nmesaz ki ena enn lepidemi dan lil = When"),
#  (161,
#   '  Dan kartye fobur, \ndan site, lor lakot ek dan sak vilaz = In the \nsubur bs, in the city, on the coast and in \neach village'),
#  (161,
#   '  Ki \nnu truve dan laktyalite tule zur = What do \nwe see in reality every day'),
#  (161,
#   ' So lalev dimi -\nuver ti pe desen enn ti surir = His half \nopen lips formed a little smile'),
#  (161,
#   '  Kikfwa \nena lalimyer dan zetol pu ki sak dimunn \nkapav truv so prop zetol = Maybe a star \nshines so that each person could fin d his \nown star'),
#  (161, ' Enn  sans li \ntruv enn bag kuler lalinn buze dan disab ='),
#  (162,
#   '  Anu fer enn \nve : ki sa bann laliny ki nu ape krir la, pu \nvinn a nba so zye = Let’s make a vow  : \nthat the lines we’ve written should be seen \nby him'),
#  (162,
#   '  Dan peyzannri \nvinn lavangard dan lalit pu sanzman = The \nvanguard for the struggle for change \ncomes from the peasantry'),
#  (162,
#   '  Guvernman ena \nlentansyon amenn nuvo lalwa = The \nGovernment has the intention to introduce \na new law'),
#  (162,
#   '  Se \nlamars anba zetol, sante puli la, zefor mo \nlebra ki ti donn li nesans = That’s the'),
#  (163,
#   '  Aster nu tu \nnu pe vinn konsyan menas ki \nglobaliz asyon kapitalist reprezante pu \ntravayer ek lamas dimunn mizer = Now \nwe’re all aware (of) the menace that \ncapizalist globalizationn represents for \nworkers and the poor masses'),
#  (163, ' Lame seme \nlizye rekolte  = The hand sows, the eyes \nharvest'),
#  (163,
#   ' Mo ti la divan li, enn marto dan \nmo lame = I was in front of him, a \nhammer in my hand'),
#  (163,
#   ' Si to dimann \nenn lepep al zet so lekor dan lamer, pu ena \nrevolisyon = If you demand that people \nthrow themselves into the sea, there w ill \nbe a revolution '),
#  (163, ' Eski ena lamer = Is there \na sea'),
#  (164,
#   ' \nApre bann Lafrik ek Lerop; apre bann \nLamerik Desid ek Lamerik Denor = After \nthose (of) Africa and Europe; then those \n(of) South America and North America'),
#  ...]

# %%
cr_en_bitext_list.pop(0)
# Out:
# (1,
#  ' Abbreviations  \nAra = Arabic  \nBan = Bantu  \nEng = English  \nFre = French  \nHin = Hindi  \nMal = Malagasy  \nredupl')

# %%
cr_en_bitext_list.pop(0)
# Out:
# (1, ' = reduplication  \n \n \n \n \n \n \n')

# %%
bitext_list = []
for pg,txt in cr_en_bitext_list:
    cl_t = txt.replace('\n','').replace('  ',' ').strip(' ')
    bitext_list.append((pg,cl_t))

# %%
bitext_list_txt = [x[1] for x in bitext_list]

# %%
def convert_list(lst,sep):
    # Initialize empty list to store converted items
    converted_lst = []
    triage_l = []

    # Loop through items in original list
    for item in lst:
        # Split item into input and target
        if item.count(sep)==1:
            input_str, target_str = item.split(sep)
            # Remove leading/trailing whitespace and strip input string of any brackets
            input_str = input_str.strip().strip('[]()')
            target_str = target_str.strip()
            # Create dictionary with input and target strings
            item_dict = {'input': input_str, 'target': target_str}
            # Add dictionary to converted list
            converted_lst.append(item_dict)
        else:
            triage_l.append(item)

    return converted_lst,triage_l

# Apply function to list
export_json,cleaner_triage_defs = convert_list(cleaned_list,':')

# %%
bitext_export_json, bitext_triage = convert_list(bitext_list_txt,'=')

# %%
import json

# %%
import json

# %%
with open('/mnt/disk/yrajcoomar/kreol-benchmark/data_collection/notebooks/cr_en_dict_sentences.json', 'w') as f:
    for item in bitext_export_json:
        # Write dictionary to file on new line
        item_dict = {'input': item['target'], 'target': item['input']}
        f.write(json.dumps(item_dict) + '\n')

# %%
len(bitext_export_json)
# Out:
# 2383

# %%
import pandas as pd

# %%
import json

dict_json = pd.read_json('/mnt/disk/yrajcoomar/kreol-benchmark/data_collection/notebooks/dict_definitions.json',lines=True)
dict_json['input'], dict_json['target'] = dict_json['target'], dict_json['input']

with open('/mnt/disk/yrajcoomar/kreol-benchmark/data_collection/notebooks/cr_en_dict_definitions.json', 'w') as f:
    for idx,item in dict_json.iterrows():
        # Write dictionary to file on new line
        item_dict = {'input': item.input, 'target': item.target}
        f.write(json.dumps(item_dict) + '\n')

# %%
dict_json = pd.read_json('/mnt/disk/yrajcoomar/kreol-benchmark/data_collection/notebooks/dict_sentences.json',lines=True)
dict_json['input'], dict_json['target'] = dict_json['target'], dict_json['input']

with open('/mnt/disk/yrajcoomar/kreol-benchmark/data_collection/notebooks/cr_en_dict_sentences.json', 'w') as f:
    for idx,item in dict_json.iterrows():
        # Write dictionary to file on new line
        item_dict = {'input': item.input, 'target': item.target}
        f.write(json.dumps(item_dict) + '\n')
